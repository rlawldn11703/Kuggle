# %% [markdown]
# # Part1 웹페이지 이해하기

# %% [markdown]
# ## Stage1 - 웹페이지와 데이터수집
# 첫번째 스테이지에서는 본격적으로 데이터수집을 시작하기 전에 우리가 수집하려는 데이터가 어디에 어떻게 저장되어있는지를 알아보려고합니다.

# %% [markdown]
# ### 웹문서와 데이터 수집의 개념 이해하기

# %% [markdown]
# <img src="image/1.png">

# %% [markdown]
# * 웹브라우저에서 마우스 오른쪽 클릭 후 <소스보기>를  클릭하면 페이지의 소스코드를 확인할 수 있습니다.

# %% [markdown]
# <img src="image/2.png">

# %% [markdown]
# * HTML이라는 웹문서를 자세히 들여다보면, 우리가 수집하기를 원하는 데이터가 어딘가에 저장되어있습니다.
# * 데이터수집(크롤링)은 바로 이 웹문서 어딘가에 저장되어 있는 데이터를 찾아 저장하는 것입니다!
# * 결국 웹문서와 친해져야 데이터를 잘 수집할 수 있을거에요.

# %% [markdown]
# ## Stage2 - HTML과 태그(tag)

# %% [markdown]
# #### HTML의 기본 구조는 아래와 같이 태그가 데이터를 감싸고 있는 구조입니다.
# #### 웹페이지의 기본구조: <태그> 데이터 </태그>

# %% [markdown]
# <img src="image/3.png">

# %% [markdown]
# #### html 문서의 태그를 통해서 수집하고자 하는 데이터를 쉽게 찾을 수 있습니다.

# %% [markdown]
# <img src="image/5.png">

# %% [markdown]
# <img src="image/4.png">

# %% [markdown]
# ### 텍스트와 관련된 간단한 태그 모음
# |태그|설명|
# |:----:|:----:|
# | h1,h2,h3,h4,h5,h6 | 제목(headline)으로 만들기 |
# | br | 한줄 띄워쓰기(break) |
# | b | 진하기(bold) |
# | u | 밑줄(underline) |
# | a | 링크 연결하기(anchor) |

# %% [markdown]
# ### 일반적인 태그의 형태 두가지
#
# 1. 첫번째 가장 일반적인 모양은 태그로 데이터가 둘러쌓여있는 형태입니다.
#
# <h1> 태그를 배워봅시다 </h1>
#
# 2. 두번째는 태그가 독립적으로 사용되는 경우입니다.
#
# 참, 띄워쓰기를 하려면 <br>br 태그를 사용해주세요 :)<br>

# %% [markdown]
# ### 여러가지 태그 연습

# %% [markdown]
# <img src="http://bit.ly/구글로고이미지">
# <div>
#  아이디: <input> <br>
#  비밀번호 <input> <br>
#  <textarea> 내용을 입력해주세요.</textarea>
# </div>

# %% [markdown]
# |태그|설명|
# |:----:|:------:|
# | img | 이미지 넣기 |
# | div | 무형의 박스 만들기 |
# | input | 입력창 만들기 |
# | textarea | 큰 입력창 만들기 |

# %% [markdown]
# ### 태그와 속성(attribute) 이해하기
# <a href="http://naver.com"> 여기 </a>를 클릭하면 네이버로 이동합니다!
# <img src="http://bit.ly/구글로고이미지">

# %% [markdown]
# **a 태그(링크 연결)**과 **img태그(이미지 넣기)**는 태그를 구성하는 <,>의 안에 **href**와 **src**라는 단어가 함께 들어있는 것을 볼 수 있는데 이와 같이 태그의 <, > 의 안에 함께 들어가서 해당하는 태그의 기능이나 모양을 결정하는 것을 속성이라고 부릅니다.

# %% [markdown]
# |태그|속성|설명|
# |:---:|:---:|:----:|
# | **img** | src | 이미지의 위치, 주소(source) |
# |  | width | 이미지의 가로크기 |
# |  | height | 이미지의 세로크기 |
# | **input** | type |입력도구의 종류를 선택합니다.(text:일반,password:별표) |
# |  |  value|입력도구의 초기값을 설정합니다. |
# |  |  placeholder|입력도구 안의 안내문을 설정합니다. |
# | textarea | rows|입력영역의 행 수(세로 길이)|
# |  |cols|입력영의 열 수(가로 길이)|
# |a|href|링크하고자 하는 페이지의 url|

# %% [markdown]
# ## Stage3 - 태그를 이용해서 원하는 데이터 찾기

# %% [markdown]
# ### 조금 더 복잡한 홈페이지 살펴보기
# 태그로 데이터를 선택할 수 있다는 사실을 알았지만, 실제 홈페이지는 더욱 복잡한 모양으로 구성되어있습니다. 그렇다면 복잡한 홈페이지에서는 어떻게 데이터를 선택할 수 있을까요? 다운받아놓은 shopping.html을 실행시켜봅니다.

# %% [markdown]
# <img src="image/7.png">

# %% [markdown]
# ### 태그의 이름, id 와 class
# #### id와 class는 일종의 속성(attribute)으로 태그의 <, >안에 포함됩니다.

# %% [markdown]
# |분류|사용|설명|
# |:---:|:---:|:---:|
# |id|<태그이름 id="아이디">|하나의 웹페이지에 하나만 쓸 수 있는 고유한 이름|
# |class|<태그이름 class="클래스">|비슷한 형태를 가진 요소에 여러번 사용할 수 있는 이름|

# %% [markdown]
# <br> 특정한 태그를 선택해달라는 명령을 컴퓨터가 수행하기 위해서는 "선택자(Selector)"라는 약속된 명령어를 사용해야합니다. <br>
# 선택자를 사용하면 원하는 class/id를 가진 태그를 쉽게 선택할 수 있습니다. <br>
# <img src="image/8.png">

# %% [markdown]
# #### 제품명: class가 title인 span 태그 `span.title`
# #### 가격: class가 price인 span 태그 `span.price`
# #### 상품명: class가 comments인 span 태그 `span.comments`

# %% [markdown]
# ### id나 class가 없는 태그는 어떻게 선택해야할까요?
# 이때는 데이터의 상하관계를 통해 특정한 태그를 선택해야합니다.

# %% [markdown]
# <img src="image/9.png"> <br>
# **a태그가 가지고 있는 span태그를 선택해줘!**

# %% [markdown]
# #### 태그의 상하관계는 아래와 같이 두가지 방법으로 표현할 수 있습니다. <br>
#
# |분류|표현|설명|
# |:---:|:---:|:---:|
# |자식(child)|a>span|a 태그가 직접 포함하고 있는 span 태그|
# |자손(descendant)|a span | a 태그가 포함하고 있는 모든 span 태그||

# %% [markdown]
# <img src="image/10.png">

# %% [markdown]
# ### 판매처를 찾는 방법: div.item>a> span

# %% [markdown]
# ## Stage4 - 진짜 웹페이지에서 데이터 선택하기

# %% [markdown]
# 이번 스테이지에서는 지난 스테이지에서 배운 선택자를 활용하여
# 진짜 웹페이지<a href="https://tv.naver.com/r/"> 네이버TV TOP 100</a>에서 1 ~ 100위까지 영상의 제목/채널명/재생 수/좋아요 수를 선택해봅시다.

# %% [markdown]
# ### 네이버TV 인기영상 선택자 찾아내기(1 - 3위 영상)
# #### 선택자 찾기: 영상 제목, 채널명, 재생 수, 좋아요 수 <br>
# 가장 먼저 영상제목을 데이터를 포함하고 있는 선택자를 찾아봅시다. 앞으로 원하는 선택자를 찾으려면 아래의 과정을 반복합니다.<br>
# 1. 내가 찾고 싶은 데이터가 웹페이지의 어디에 있는지 확인합니다.
# 2. 검사(Inspect)창을 켜고 내가 원하는 데이터를 포함하고 있는 코드를 찾습니다.
# 3. 해당하는 코드를 선택하는 선택자를 확인합니다.
# 4. 검색을 통해 적절한 선택자를 골랐는지 확인합니다.

# %% [markdown]
# 컨테이너: <span style="color:white"> div.inner <br> </span>
# 제목: <span style="color:white"> dt.title <br> </span>
# 채널명: <span style="color:white"> dd.chn <br> </span>
# 재생 수: <span style="color:white"> span.hit <br> </span>
# 좋아요 수: <span style="color:white"> span.like <br> </span>

# %% [markdown]
# # Part2 파이썬으로 데이터 수집하기

# %% [markdown]
# ## Stage1 - 파이썬과 오픈소스 패키지

# %% [markdown]
# ### 파이썬 오픈소스 패키지(Package)
# 개인 또는 회사가 작성하여 무료로 배포하는 코드들을 오픈소스 패키지라고 부르며 우리가 익숙한 웹서비스들의 기능들도 이러한 오픈소스 패키지를 활용하여 만든 경우가 많습니다.
# <img src="image/11.png">

# %% [markdown]
# ### 오픈소스 패키지 다운로드/사용
# 파이썬에서는 Python Package Index(PIP)를 활용하면 쉽게 오픈소스 패키지들을 다운로드받고 또 업데이트할 수 있습니다.
# <img src="image/12.png">

# %% [markdown]
# ### 터미널 창에 아래와 같이 명령어를 입력하면 원하는 패키지가 설치됩니다.
# `pip install 패키지` <br>
#
# |패키지 다운로드/사용|명령어|
# |:---:|:---:|
# |패키지 설치|pip install 패키지이름 |
# |패키지 업데이트|pip install --upgrade 패키지이름|
# |패키지 삭제|pip uninstall 패키지이름|

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\anaconda\envs\jiwoo\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\envs\jiwoo\lib\site-packages (from requests) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda\envs\jiwoo\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\jiwoo\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda\envs\jiwoo\lib\site-packages (from requests) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\envs\jiwoo\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\envs\jiwoo\lib\site-packages (from beautifulsoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Stage2 - 파이썬으로 데이터 수집하기

# %%
raw=requests.get("http://tv.naver.com/r/") #get()을 통해 페이지의 정보를 가지고 와서 raw에 저장
#print(raw) #성공적으로 가지고 온 것을 확인 가능
print(raw.text) #raw의 소스코드를 확인 가능
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#
#
#
#
# <head>
#     <title id="headTitle">
#
#
#
#     		인기영상
#
#     </title>
#     <meta charset="utf-8">
#     <meta http-equiv="Content-Script-Type" content="text/javascript">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="robots" content="noindex">
#
#
#
#
#
#
#
#
#
#
#
#     <meta name="twitter:card" content="summary">
#
#
#
#
#     <meta property="fb:admins" content="100012287952710" />
#     <meta property="fb:app_id" content="232491033870086" />
#
#     <meta property="og:url" content='https://tv.naver.com/r/'>
#     <meta property="og:title" content="Top100 : 네이버TV">
#     <meta property="og:description" content="동영상을 감상하는 가장 쉽고 빠른 방법">
#
#     <meta property="og:type" content='website'>
#
#
#
#
#
#
#
#     <meta property="og:image" content='https://ssl.pstatic.net/img.tvcast/common/img/og/180629/OG_Tag_270_270.png'>
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href='/resources/release/css/tvcast_20200910150919.css'  />
#     <link rel="stylesheet" type="text/css" href='/resources/release/css/contest_20200910150919.css'  />
#
#     <script type="text/javascript" src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/jQuery.1.11.3.min.js"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/jQuery.cookie.1.4.1.min.js"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/img.tvcast/pc/js/eg/eg.1.3.0.pkgd.min.js"></script>
#     <script type="text/javascript" src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/perfect-scrollbar.jquery.min.js"></script>
#
#     <script type="text/javascript">
#         jQuery.noConflict();
#
#         jQuery.cookie.defaults.path = '/';
#
#         jQuery.ajaxSetup({
#             cache: true
#         });
#     </script>
#
#     <script type="text/javascript" src='/resources/release/js_v2/clickcr_20200910150919.js'></script>
#     <script type="text/javascript" src='/resources/release/js_v2/tvcast.Common_20200910150919.js'></script>
#
#
#
#
#
#
#
#
#
#
#
#
#         <script src="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.web.sdk.js"></script>
# 	    <link rel="stylesheet" href="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.adplayer.css" />
# 		<link rel="stylesheet" href="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.nonlinear.css" />
#
#
#
#     <!--[if lt IE 9]>
#     <script type="text/javascript" src='/resources/release/js_v2/respond/respond.src_20200910150919.js'></script>
#     <![endif]-->
# </head>
#
#
#
#
#
#
#
#
# <body class="    ">
# <div id="u_skip">
#     <a href="#aside" onclick="document.getElementById('aside').tabIndex=-1;document.getElementById('aside').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
#     <a href="#container" id="gnb_goContent" onclick="document.getElementById('container').tabIndex=-1;document.getElementById('container').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="wrap">
#
#
#
#
#
#
#
#
#
#
#
# <!--[if lt IE 9]>
#
# <div class="notice_bnr" id="notice_bnr">
# 	<strong class="txt_notice">지금 사용중인 브라우저는 7월 이후 동영상 재생이 불가능합니다. 빠르고 안전한 <a href="https://whale.naver.com/ko/" target="_blank" class="link_whale" onclick="clickcr(this, 'STA.whaledown', '','');"><img src="https://ssl.pstatic.net/static/tv/navertv/pc/img/img_whale.png" width="28" height="20" alt="" class="icon_whale">네이버 웨일</a>로 업데이트 하세요!</strong>
# 	<a href="https://help.naver.com/support/contents/contents.help?serviceNo=3609&categoryNo=22360" target="_blank" class="link_notice" onclick="clickcr(this, 'STA.help', '','');">도움말 보기 <img src="https://ssl.pstatic.net/static/tv/navertv/pc/img/top_notice_arr.png" width="6" height="10" alt="" class="icon_arr"></a>
# </div>
#
# <![endif]-->
#
# <div id="header">
# 	<iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:60px;border:none;vertical-align:bottom" title="빈 프레임"></iframe>
#
# 	<div class="header_wrap">
# 		<div class="header_content">
# 			<h1 class="head_logo">
# 				<a href="https://tv.naver.com" class="logo_navertv">
# 					<span class="blind">네이버 TV</span>
# 				</a>
# 			</h1>
#
# 			<div class="head_search">
#
# 				<div class="search _searchAutoComplete" id="searchBoxWrapper">
# 					<form id="searchForm">
# 						<fieldset>
# 							<legend>검색</legend>
# 							<div class="input_wrap">
# 								<span class="ipt_srch">
# 									<label for="searchQuery" class="blind">검색어를 입력하세요.</label>
# 									<input id="searchQuery" class="" name="query" value="" type="text" placeholder="검색어를 입력하세요" title="검색어를 입력하세요" style="width:100%" autocomplete="off">
# 									<span class="auto_tx"><a href="#" class="_autoTxLink _toggle_btn" onclick="return false;"><img class="_arrow" src="https://ssl.pstatic.net/static/tv/navertv/pc/img/icon_searchbar_arr_down.png" width="8" height="5" id="acButton" alt="자동완성 펼치기"></a></span>
# 								</span>
# 								<a href="javascript:;" title="검색" id="searchButton" class="btn_search">검색</a>
#
# 								<div class="auto_tx_area ly_atcmp wrap _suggestView" id="acView" style="display:none;">
# 									<iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="검색 폼"></iframe>
#
# 									<div class="wrap_recent_search" id="recentKeywordView" style="display:none">
# 										<div class="recent_search_header">
# 											<p class="tit">최근 검색어</p>
# 										</div>
# 										<ul class="list_recent_search _resentSearchBox" style="display:block" id="recentResultBox">
# 											<li data-order="@order@" data-search-type="recent" data-keyword="@inKeyword@">
# 												<a href="javascript:void(0)" class="recent_keyword" onclick="clickcr(this, 'STA.searchrecent', '', '', event)">
# 													<span class="recent_keyword_txt">@keyword@</span>
# 												</a>
# 												<a href="javascript:void(0)" class="btn_del_keyword _recentKeywordDeleteBtn">
# 													<span class="blind">삭제</span>
# 												</a>
# 											</li>
# 										</ul>
# 									</div>
#
#
#
# 									<div class="auto_txt words _resultArea" id="autocompleteView" style="display:none">
# 										<ul class="_resultBox">
# 											<li data-search_type="not used">
# 												<a href="javascript:void(0);" class="atcmp_keyword">
# 													<span class="atcmp_keyword_img">@imageTag@</span>
# 													<span class="atcmp_keyword_txt">@txt@</span>
# 												</a>
# 											</li>
# 										</ul>
#
# 										<ul class="_resultBox list_keyword_hash">
# 											<li data-search-type="tag" data-txt="@in_txt@">
# 												<a href="javascript:void(0);" class="atcmp_keyword">
# 													<span class="atcmp_keyword_hash"><span class="blind">#</span></span>
# 													<span class="atcmp_keyword_txt">@txt@</span>
# 												</a>
# 											</li>
# 										</ul>
#
# 										<ul class="_resultBox list_keyword_ch">
# 											<li data-search-type="channel" data-display-channel-id="@linkUrl@" data-txt="@in_txt@">
# 												<a href="javascript:void(0);" class="atcmp_keyword">
# 													<span class="atcmp_keyword_img">@imageTag@</span>
# 													<span class="atcmp_keyword_txt">@txt@</span>
# 												</a>
# 											</li>
# 										</ul>
#
# 									</div>
# 									<p class="at_alert _alert" id="autocompleteAlertView" style="display:none;top:578px">자동완성 기능이 활성화되었습니다.</p>
# 									<div class="auto_tx_foorer _footer" id="autocompleteAllView">
# 										<a href="#" id="searchButtonAll" class="all_result _search" onclick="return false;">전체 검색 결과보기</a>
# 										<p class="auto_tx_etc">
# 											<a href="#" class="clse _unuse_btn" onclick="return false;">자동완성 끄기</a>
# 										</p>
# 										<img src="https://ssl.pstatic.net/img.tvcast/pc/img/img_atcmp.png" width="268" height="28" class="help _use_guide" style="display:none;position:absolute;bottom:25px;right:4px" alt="기능을 다시 켤 때는 자동완성 펼치기를 선택하세요.">
# 									</div>
# 								</div>
# 							</div>
# 						</fieldset>
# 					</form>
# 				</div>
#
# 			</div>
#
#
# 			<div class="gnb_wrap">
# 				<a href="https://studio.tv.naver.com" class="btn_gnb btn_cs" onclick="clickcr(this, 'STA.studio', '', '');" aria-label="Creator Studio 바로가기"></a>
# 				<a href="https://studio.tv.naver.com/clip/register" class="btn_gnb btn_upload" onclick="clickcr(this, 'STA.upload', '', '');" aria-label="동영상 업로드"></a>
#
# 				<div id="gnb" class="gnb_my">
#
# 						<a href="https://nid.naver.com/nidlogin.login" class="btn_gnb btn_login _btnLogin" onclick="clickcr(this, 'STA.login', '', '');">로그인</a>
#
#
#
#
# 					<a href="#" class="btn_mymenu _btnMyMenu" role="button" aria-label="나의 메뉴 보기" aria-haspopup="true" aria-expanded="false" style="display: none;">
# 						<img src="https://ssl.pstatic.net/static/common/myarea/myInfo.gif" class="_btnMyMenuImg" width="28" height="28" alt="프로필 사진">
# 					</a>
#
# 					<div class="layer_mymenu _layerMyMenu">
#
#
# 								<div class="mychannel_none">
# 									<p class="guide">
# 										보유하고 있는 채널이 없습니다. <br>
# 										지금 채널을 만들어 보세요.
# 									</p>
# 									<a class="link" href="https://studio.tv.naver.com/channel/register" onclick="clickcr(this, 'MYP.create', '', '');">채널 만들기</a>
# 								</div>
#
#
#
#
# 						<a class="btn_logout _btnLogOut" href="https://nid.naver.com/nidlogin.logout" onclick="clickcr(this, 'MYP.logout', '', '');" role="button">로그아웃</a>
# 					</div>
#
# 				</div>
# 			</div>
#
# 		</div>
# 	</div>
# </div>
#
# <script type="text/javascript">
# 	var ghtGnb = {
# 		sRequestUrl: 'https://ac.tv.naver.com/ac',
# 		sAutoCompleteV2: '/resources/release/js_v2/service_common/nautocomplete_20200910150919.js',
# 		sAutoCompleteV2View: '/resources/release/js_v2/service_common/tvcast.pc.SuggestView_20200910150919.js',
# 		sAutoTemplateImageTag: '<img src="https://phinf.pstatic.net/tvcast@emblemUrl@?type=round_31_31" onerror="this.src=\'https://phinf.pstatic.net/tvcast/20161227_13/photoinfra_1482831946369BANUd_PNG/default_round_ch.png?type=round_31_31\'" width="22" height="22" alt="임시 이미지">',
# 		bIsLogin : false
# 	};
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="aside" class="side_menu" role="navigation">
# 	<iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="빈 프레임"></iframe>
# 	<button id="menuButton" class="btn_aside" type="button" aria-label="메뉴" aria-labelledby="asideToolTip"></button>
#
#
# 	<div class="aside_wrap _sideMenu" aria-hidden="false">
# 		<div id="menuScrollBox" class="scrollbar">
# 			<ul class="list_snb _asideListSnb">
#
# 				<li class="snb_home _listSnbHome">
# 					<a class="link_snb" href="https://tv.naver.com/" onClick="clickcr(this, 'mnu.home', '', '', event)">
# 						<span class="icon icon_home"></span>
# 						<span class="title">홈</span>
# 					</a>
# 				</li>
#
# 				<li class="snb_popular _listSnbPopular">
# 					<a class="link_snb" href="https://tv.naver.com/r/" onClick="clickcr(this, 'mnu.popular', '', '', event)">
# 						<span class="icon icon_popular"></span>
# 						<span class="title">인기영상</span>
# 					</a>
# 				</li>
#
# 				<li class="snb_live _listSnbLive">
# 					<a class="link_snb" href="https://tv.naver.com/l/livehome" onClick="clickcr(this, 'mnu.livetb', '', '', event)">
# 						<span class="icon icon_live"></span>
# 						<span class="title">라이브<span class="icon_beta"><span class="blind">"beta"</span></span></span>
# 					</a>
#
# 				</li>
#
#
#
# 				<li class="snb_my _listSnbMy">
# 					<a class="link_snb" href="/my/playlist/?type=recent" onClick="clickcr(this, 'mnu.my', '', '', event)">
# 						<span class="icon icon_my"></span>
# 						<span class="title">MY</span>
# 					</a>
#
# 					<input class="snb_toggle _snbToggle" data-toggletype="MY" type="checkbox" name="subMenu" onClick="clickcr(this, 'mnu.mymore', '', '', event)" id="subMenu1" aria-hidden="false">
# 					<label class="btn_sub" for="subMenu1" role="button" tabindex="0" aria-label="하위 메뉴 토글"></label>
#
# 					<ul class="list_sub">
#
# 						<li class="_listSubMyRecent">
# 							<a href="https://tv.naver.com/my/playlist/?type=recent" class="menu_cnt" onClick="clickcr(this, 'mnu.watched', '', '', event)">최근 본 영상</a>
# 						</li>
# 						<li class="_listSubMyWatchlater">
# 							<a href="https://tv.naver.com/my/playlist/?type=watch_later" class="menu_cnt" onClick="clickcr(this, 'mnu.history', '', '', event)">나중에 볼 영상</a>
# 						</li>
# 						<li class="_listSubMyLikeit">
# 							<a href="https://tv.naver.com/my/playlist/?type=likeit" class="menu_cnt" onClick="clickcr(this, 'mnu.like', '', '', event)">좋아요 한 영상</a>
# 						</li>
# 					</ul>
# 				</li>
#
#
# 				<li id="myArea" class="snb_feed _listSnbFeed _myMenu" data-login="false">
#
#
#
#
#
#
#
#
#
#
# <a class="link_snb" href="https://tv.naver.com/my/subscription/updated" onClick="clickcr(this, 'mnu.feed', '', '', event)">
# 	<span class="icon icon_feed"></span>
# 	<span class="title">구독</span>
# </a>
#
#
#
#
#
#
#
#
# 		<p class="nolist">
# 			관심있는 채널을 구독하여<br>업데이트 동영상을 받아보세요.
# 			<a class="btn_ch_search" href="/r/channel" onClick="clickcr(this, 'mnu.watch', '', '', event)">채널 탐색하기</a>
# 		</p>
#
#
#
# 				</li>
#
#
# 				<li class="snb_theme _listSnbTheme _exclusiveMenu" id="brandArea">
# 					<a class="link_snb" href="/p/class" onClick="clickcr(this, 'mnu.theme', '', '', event)">
# 						<span class="icon icon_theme"></span>
# 						<span class="title">테마</span>
# 					</a>
#
# 					<input class="snb_toggle _snbToggle" data-toggletype="THEME" type="checkbox" name="subMenu" id="subMenu3" onClick="clickcr(this, 'mnu.thememore', '', '', event)" aria-hidden="false">
# 					<label class="btn_sub" for="subMenu3" role="button" tabindex="0" aria-label="하위 메뉴 토글"></label>
#
# 					<ul class="list_sub _brand">
# 					</ul>
#
#
# 					<a href="#" class="btn_list_sub_more _click _exclusiveMenuFoldState" data-event="foldExclusiveMenu">더보기</a>
# 				</li>
#
# 				<li id="smrBrandArea" class="snb_broad _listSnbBrand">
# 					<a class="link_snb" href="/b/tvchosun" onClick="clickcr(this, 'mnu.media', '', '', event)">
# 						<span class="icon icon_broad"></span>
# 						<span class="title">방송관</span>
# 					</a>
#
# 					<input class="snb_toggle _snbToggle" data-toggletype="BRAND" type="checkbox" name="subMenu" id="subMenu4" onClick="clickcr(this, 'mnu.mediamore', '', '', event)" aria-hidden="false">
# 					<label class="btn_sub" for="subMenu4" role="button" tabindex="0" aria-label="하위 메뉴 토글"></label>
#
# 					<ul class="list_sub _smrBrand">
# 					</ul>
# 				</li>
#
# 				<li class="snb_etc _listSnbEtc">
# 					<ul class="list_sub">
#
# 						<li class="_listSubPatron">
# 							<a href="/special/patron" onClick="clickcr(this, 'mnu.patron', '', '', event)">후원하기<span class="icon_beta"><span class="blind">"beta"</span></span></a>
# 						</li>
# 						<li class="_listSubPlay">
# 							<a href="/play/" onClick="clickcr(this, 'mnu.playleague', '', '', event)">플레이리그</a>
# 						</li>
# 						<li class="_listSubNstore">
# 							<a href="http://serieson.naver.com/broadcasting/home.nhn" onClick="clickcr(this, 'mnu.tvlink', '', '', event)" target="_blank">방송 다시보기</a>
# 						</li>
# 						<li class="_listSubBlog">
# 							<a href="http://blog.naver.com/nv_tvcast" target="_blank" onClick="clickcr(this, 'mnu.attention', '', '', event)">공식블로그</a>
# 						</li>
# 					</ul>
# 				</li>
# 			</ul>
# 		</div>
# 	</div>
#
#
#
#
# 	<ul class="fold_snb _foldSnb" aria-hidden="true">
# 		<li class="snb_home _listSnbHomeFold">
# 			<a class="link_snb" href="https://tv.naver.com/" onClick="clickcr(this, 'mnu.home', '', '', event)" aria-label="홈">
# 				<span class="icon icon_home"></span>
# 			</a>
# 		</li>
#
# 		<li class="snb_popular _listSnbPopularFold">
# 			<a class="link_snb" href="https://tv.naver.com/r/" onClick="clickcr(this, 'mnu.top100', '', '', event)" aria-label="인기영상">
# 				<span class="icon icon_popular"></span>
# 			</a>
# 		</li>
#
# 		<li class="snb_live _listSnbLiveFold">
# 			<a class="link_snb" href="https://tv.naver.com/l/livehome" onClick="clickcr(this, 'mnu.livetb', '', '', event)" aria-label="라이브">
# 				<span class="icon icon_live"></span>
# 			</a>
# 		</li>
#
# 		<li class="snb_my _listSnbMyFold">
# 			<a class="link_snb" href="/my/playlist/?type=recent" onClick="clickcr(this, 'mnu.my', '', '', event)" aria-label="MY">
# 				<span class="icon icon_my"></span>
# 			</a>
# 		</li>
#
# 		<li class="snb_feed _listSnbFeedFold">
# 			<a class="link_snb" href="https://tv.naver.com/my/subscription/updated" onClick="clickcr(this, 'mnu.update', '', '', event)" aria-label="구독">
# 				<span class="icon icon_feed"></span>
# 			</a>
# 		</li>
#
# 		<li class="snb_theme _listSnbThemeFold">
# 			<a class="link_snb" href="/p/class" onClick="clickcr(this, 'mnu.theme', '', '', event)" aria-label="테마">
# 				<span class="icon icon_theme"></span>
# 			</a>
# 		</li>
# 	</ul>
#
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="container">
# 	<div class="top100">
#
#
#
#
#
#
#
#
#
# <div class="cate_tit2">
#     <div class="tit_wrap">
#         <div class="tit_area">
#             <h2><span>인기</span></h2>
#         </div>
#
#         <div class="cate_sort">
#             <ul>
#                 <li class="on">
#                     <a href="https://tv.naver.com/r/"  onclick="clickcr(this, 'tab.top100tab', '', '', event)">
#                         <span>TOP100</span>
#                     </a>
#                 </li>
#                 <li class="">
#                     <a href="https://tv.naver.com/i/"  onclick="clickcr(this, 'tab.ntoptab', '', '', event)">
#                         <span>지금 뜨는</span>
#                     </a>
#                 </li>
#             </ul>
#         </div>
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
# 	<div class="top_main">
# 		<div class="main_wrap">
# 				<div class="top_spot">
# 					<h2><span class="blind">네이버TV 인기</span></h2>
#
# 						<p class="noti">9.15 오후 7시 ~ 오후 8시 기준 (재생수, 재생시간)</p>
#
# 					<div class="top_flick">
# 						<ul class="rolling">
#
# 							<li>
# 								<div class="inner">
# 									<a href="https://tv.naver.com/v/15789022/list/67096" class="box" onclick="clickcr(this, 'top.3clip', '', '1', event)"
# 									   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_58/lxfy5_1600162081029nlJ8y_GIF/2ee893fd-f72b-11ea-b157-b496915d9eb0.gif?type=mfullfill_406_228_ani_limit15">
# 										<span class="mask _top_ani_area"></span>
# 										<img src="https://phinf.pstatic.net/tvcast/20200915_153/KcBJO_1600157575404Qw7B6_JPEG/CA202009150048.jpg?type=f406_228_blend"
# 											 data-src="https://phinf.pstatic.net/tvcast/20200915_153/KcBJO_1600157575404Qw7B6_JPEG/CA202009150048.jpg?type=f406_228_blend"
# 											 alt="&#039;보는 재미가 있는 투수입니다&#039; 김광현, 주요장면 현지 반응" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"'>
# 										<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" alt="임시 이미지">
# 										<em class="time"><span class="blind">재생시간</span>3:35</em>
# 										<span class="btn_my _click" data-event="addWatchLater" data-clipno="15789022" data-login="false" onclick="clickcr(this, 'top.3add', '', '1', '');">담기</span>
# 									</a>
# 									<div class="info">
#
# 										<span class="num num1">1</span>
#
#
#
# 											<span class="rank up"><span class="blind">상승</span><em>3</em></span>
#
#
#
# 										<dl class="cds_info">
# 											<dt class="title">
# 												<a href="https://tv.naver.com/v/15789022" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# 													<strong class="tit"><span>&#039;보는 재미가 있는 투수입니다&#039; 김광현, 주요장면 현지 반응</span></strong>
# 												</a>
# 											</dt>
# 											<dd class="chn">
# 												<a href="https://tv.naver.com/mbc.kimkwanghyun" class="ch" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">김광현 (세인트루이스 카디널스)</a>
# 											</dd>
# 											<dd class="meta">
# 												<span class="hit"><span class="blind">재생 수</span>58,955</span>
# 												<span class="like"><span class="blind">좋아요 수</span>344</span>
# 											</dd>
# 										</dl>
# 									</div>
# 								</div>
# 							</li>
#
# 							<li>
# 								<div class="inner">
# 									<a href="https://tv.naver.com/v/15778620/list/67096" class="box" onclick="clickcr(this, 'top.3clip', '', '2', event)"
# 									   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_194/veCNV_16001458682989UCmy_GIF/f24bb78a-f70f-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15">
# 										<span class="mask _top_ani_area"></span>
# 										<img src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend"
# 											 data-src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend"
# 											 alt="&#039;Rookie of the year?&#039; 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"'>
# 										<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" alt="임시 이미지">
# 										<em class="time"><span class="blind">재생시간</span>10:41</em>
# 										<span class="btn_my _click" data-event="addWatchLater" data-clipno="15778620" data-login="false" onclick="clickcr(this, 'top.3add', '', '2', '');">담기</span>
# 									</a>
# 									<div class="info">
#
# 										<span class="num num2">2</span>
#
#
#
#
# 											<span class="rank down"><span class="blind">하락</span><em>1</em></span>
#
#
# 										<dl class="cds_info">
# 											<dt class="title">
# 												<a href="https://tv.naver.com/v/15778620" onclick="clickcr(this, 'top.3clip', '', '2', event)">
# 													<strong class="tit"><span>&#039;Rookie of the year?&#039; 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]</span></strong>
# 												</a>
# 											</dt>
# 											<dd class="chn">
# 												<a href="https://tv.naver.com/mbc.kimkwanghyun" class="ch" onclick="clickcr(this, 'top.3chtitle', '', '2', event)">김광현 (세인트루이스 카디널스)</a>
# 											</dd>
# 											<dd class="meta">
# 												<span class="hit"><span class="blind">재생 수</span>317,072</span>
# 												<span class="like"><span class="blind">좋아요 수</span>4,126</span>
# 											</dd>
# 										</dl>
# 									</div>
# 								</div>
# 							</li>
#
# 							<li>
# 								<div class="inner">
# 									<a href="https://tv.naver.com/v/15786826/list/67096" class="box" onclick="clickcr(this, 'top.3clip', '', '3', event)"
# 									   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_11/42V7T_1600164702361ByNjm_GIF/83020471-f73b-11ea-ae86-b496915d8e58.gif?type=mfullfill_406_228_ani_limit15">
# 										<span class="mask _top_ani_area"></span>
# 										<img src="https://phinf.pstatic.net/tvcast/20200915_49/Hzx1G_1600159303537SPbLs_JPEG/clip_TT202009150042_20200915173447.jpg?type=f406_228_blend"
# 											 data-src="https://phinf.pstatic.net/tvcast/20200915_49/Hzx1G_1600159303537SPbLs_JPEG/clip_TT202009150042_20200915173447.jpg?type=f406_228_blend"
# 											 alt="[환불원정대 후공개 - 후불원정대] 데뷔전 이효리와 엄정화의 만남?! 이야기가 넘치는 만옥 하우스..✨" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"'>
# 										<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" alt="임시 이미지">
# 										<em class="time"><span class="blind">재생시간</span>5:06</em>
# 										<span class="btn_my _click" data-event="addWatchLater" data-clipno="15786826" data-login="false" onclick="clickcr(this, 'top.3add', '', '3', '');">담기</span>
# 									</a>
# 									<div class="info">
#
# 										<span class="num num3">3</span>
#
#
#
#
# 											<span class="rank down"><span class="blind">하락</span><em>1</em></span>
#
#
# 										<dl class="cds_info">
# 											<dt class="title">
# 												<a href="https://tv.naver.com/v/15786826" onclick="clickcr(this, 'top.3clip', '', '3', event)">
# 													<strong class="tit"><span>[환불원정대 후공개 - 후불원정대] 데뷔전 이효리와 엄정화의 만남?! 이야기가 넘치는 만옥 하우스..✨</span></strong>
# 												</a>
# 											</dt>
# 											<dd class="chn">
# 												<a href="https://tv.naver.com/mbc.howdoyouplay" class="ch" onclick="clickcr(this, 'top.3chtitle', '', '3', event)">놀면 뭐하니?</a>
# 											</dd>
# 											<dd class="meta">
# 												<span class="hit"><span class="blind">재생 수</span>62,363</span>
# 												<span class="like"><span class="blind">좋아요 수</span>411</span>
# 											</dd>
# 										</dl>
# 									</div>
# 								</div>
# 							</li>
#
# 						</ul>
# 					</div>
# 				</div>
# 		    </div>
# 	</div>
#
# 	<div id="content">
# 		<div class="top100_mv">
# 			<div class="wrp_cds">
# 				<div class="cds_area">
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/13506302/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '4', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200424_14/fdxk0_1587654377208FB5tO_GIF/1dd3ae5f-856e-11ea-b412-b496915e8f50.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200423_250/7RfxA_158765201233492bIr_JPEG/C202000040_3_202004231110485551.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200423_250/7RfxA_158765201233492bIr_JPEG/C202000040_3_202004231110485551.jpg?type=f194_109_blend"
# 									 width="100%" alt="감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>3:53</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="13506302" data-login="false" onclick="clickcr(this, 'top.add', '', '4', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num4">4</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
# 	                  			<span class="rank up"><span class="blind">상승</span><em>5</em></span>
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/13506302/list/67096" onclick="clickcr(this, 'top.clip', '', '4', event)" title="감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬"><tooltip>감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '4', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>739,909</span>
# 									<span class="like"><span class="blind">좋아요 수</span>32,316</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15790250/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '5', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_100/pU8JD_16001631099411GzRH_GIF/b7d175eb-f730-11ea-a65d-b496915e8884.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_35/6j6XZ_1600159965590LtxsD_JPEG/f9c7faf6-832d-4fd3-b684-f5d8cd3f047b.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_35/6j6XZ_1600159965590LtxsD_JPEG/f9c7faf6-832d-4fd3-b684-f5d8cd3f047b.jpg?type=f194_109_blend"
# 									 width="100%" alt="[스페셜] “너무 귀엽당♡” 모든 게 귀여운 강남♥이상화 모음.ZIP" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>24:47</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15790250" data-login="false" onclick="clickcr(this, 'top.add', '', '5', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num5">5</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
# 	                  			<span class="rank new"><em>NEW</em></span>
#
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15790250/list/67096" onclick="clickcr(this, 'top.clip', '', '5', event)" title="[스페셜] “너무 귀엽당♡” 모든 게 귀여운 강남♥이상화 모음.ZIP"><tooltip>[스페셜] “너무 귀엽당♡” 모든 게 귀여운 강남♥이상화 모음.ZIP</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/sbs.woori" onclick="clickcr(this, 'top.chtitle', '', '5', event)">미운 우리 새끼</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>13,808</span>
# 									<span class="like"><span class="blind">좋아요 수</span>56</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/14391626/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '6', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200622_78/tC2bL_1592785901711LCeGP_GIF/2d497aa2-b2e0-11ea-8648-a0369ff9072c.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200622_220/uBlso_1592785900541gsL9T_PNG/eFT91uWEo87N.png?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200622_220/uBlso_1592785900541gsL9T_PNG/eFT91uWEo87N.png?type=f194_109_blend"
# 									 width="100%" alt="김호중 - 어느 60대 노부부의 이야기" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>6:13</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="14391626" data-login="false" onclick="clickcr(this, 'top.add', '', '6', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num6">6</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
# 	                  			<span class="rank up"><span class="blind">상승</span><em>1</em></span>
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/14391626/list/67096" onclick="clickcr(this, 'top.clip', '', '6', event)" title="김호중 - 어느 60대 노부부의 이야기"><tooltip>김호중 - 어느 60대 노부부의 이야기</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/satfreedom" onclick="clickcr(this, 'top.chtitle', '', '6', event)">불후의 명곡2 전설을 노래하다</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>891,016</span>
# 									<span class="like"><span class="blind">좋아요 수</span>32,366</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15781126/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '7', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_5/e65qe_160013928181755PFO_GIF/893e1817-f700-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_133/evtTk_1600139278456sD1Ep_JPEG/CA202009150027.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_133/evtTk_1600139278456sD1Ep_JPEG/CA202009150027.jpg?type=f194_109_blend"
# 									 width="100%" alt="세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>16:02</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15781126" data-login="false" onclick="clickcr(this, 'top.add', '', '7', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num7">7</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
#
# 	                  			<span class="rank keep"><span class="blind">유지</span><em></em></span>
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15781126/list/67096" onclick="clickcr(this, 'top.clip', '', '7', event)" title="세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)"><tooltip>세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/mbc.MSPNEWS009" onclick="clickcr(this, 'top.chtitle', '', '7', event)">MLB 핫클립</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>44,134</span>
# 									<span class="like"><span class="blind">좋아요 수</span>22</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15789900/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '8', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_62/oFWEA_1600165061414V2ErE_GIF/f84acfde-f72e-11ea-a56a-a0369ff968ac.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_224/oGLOF_1600159306349WJwPs_JPEG/B120206869_EPI0011_04_B.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_224/oGLOF_1600159306349WJwPs_JPEG/B120206869_EPI0011_04_B.jpg?type=f194_109_blend"
# 									 width="100%" alt="[비하인드] 조승우가 직접 밝힌 대대손손 전해내려온 &#039;낚시 전설&#039; 의 비밀 ☆" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>4:53</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15789900" data-login="false" onclick="clickcr(this, 'top.add', '', '8', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num8">8</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
# 	                  			<span class="rank up"><span class="blind">상승</span><em>46</em></span>
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15789900/list/67096" onclick="clickcr(this, 'top.clip', '', '8', event)" title="[비하인드] 조승우가 직접 밝힌 대대손손 전해내려온 &#039;낚시 전설&#039; 의 비밀 ☆"><tooltip>[비하인드] 조승우가 직접 밝힌 대대손손 전해내려온 &#039;낚시 전설&#039; 의 비밀 ☆</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/cjenm.tvnstranger2" onclick="clickcr(this, 'top.chtitle', '', '8', event)">비밀의 숲2</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>17,081</span>
# 									<span class="like"><span class="blind">좋아요 수</span>297</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15791874/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '9', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_107/PL703_16001645891643cEpO_GIF/949f99c3-f73b-11ea-957a-b496915e8f50.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_230/WKnx9_1600164551267D9v6a_JPEG/1.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_230/WKnx9_1600164551267D9v6a_JPEG/1.jpg?type=f194_109_blend"
# 									 width="100%" alt="&#039;승점 5점짜리 더비&#039; 행운의 크로스로 선제골을 기록하는 바로우 / 전반 1분" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>1:11</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15791874" data-login="false" onclick="clickcr(this, 'top.add', '', '9', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num9">9</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
# 	                  			<span class="rank new"><em>NEW</em></span>
#
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15791874/list/67096" onclick="clickcr(this, 'top.clip', '', '9', event)" title="&#039;승점 5점짜리 더비&#039; 행운의 크로스로 선제골을 기록하는 바로우 / 전반 1분"><tooltip>&#039;승점 5점짜리 더비&#039; 행운의 크로스로 선제골을 기록하는 바로우 / 전반 1분</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/kleague" onclick="clickcr(this, 'top.chtitle', '', '9', event)">K LEAGUE 1 네이버스포츠</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>25,938</span>
# 									<span class="like"><span class="blind">좋아요 수</span>221</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15709947/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '10', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200911_28/gYiRO_1599758167542sKXly_GIF/018dabdc-f37b-11ea-a544-a0369ff969f4.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200911_63/XUUX3_1599752212071xiQvI_JPEG/C202000040_3_202009101111372471.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200911_63/XUUX3_1599752212071xiQvI_JPEG/C202000040_3_202009101111372471.jpg?type=f194_109_blend"
# 									 width="100%" alt="빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>3:48</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15709947" data-login="false" onclick="clickcr(this, 'top.add', '', '10', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num10">10</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
#
# 	                  			<span class="rank keep"><span class="blind">유지</span><em></em></span>
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15709947/list/67096" onclick="clickcr(this, 'top.clip', '', '10', event)" title="빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬"><tooltip>빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '10', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>119,258</span>
# 									<span class="like"><span class="blind">좋아요 수</span>10,954</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15776974/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '11', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_233/jT54a_1600120299145y5b1A_GIF/7653bb9e-f6d4-11ea-8dce-a0369faad059.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_297/4XgUb_1600120128168YxIFN_JPEG/20200915_BRI_CHE_HL.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_297/4XgUb_1600120128168YxIFN_JPEG/20200915_BRI_CHE_HL.jpg?type=f194_109_blend"
# 									 width="100%" alt="1R 브라이튼 vs 첼시 경기 하이라이트" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>11:20</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15776974" data-login="false" onclick="clickcr(this, 'top.add', '', '11', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num11">11</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
#
# 	                  			<span class="rank keep"><span class="blind">유지</span><em></em></span>
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15776974/list/67096" onclick="clickcr(this, 'top.clip', '', '11', event)" title="1R 브라이튼 vs 첼시 경기 하이라이트"><tooltip>1R 브라이튼 vs 첼시 경기 하이라이트</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/eplnv" onclick="clickcr(this, 'top.chtitle', '', '11', event)">SPOTV_PL</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>138,430</span>
# 									<span class="like"><span class="blind">좋아요 수</span>389</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15159840/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '12', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200806_146/c8eK4_159672506406193IrR_GIF/da9158b6-d7f1-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200806_201/TaIl7_159672461283118w2G_JPEG/C202000040_3_202008061113453621.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200806_201/TaIl7_159672461283118w2G_JPEG/C202000040_3_202008061113453621.jpg?type=f194_109_blend"
# 									 width="100%" alt="임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대.." onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>3:57</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15159840" data-login="false" onclick="clickcr(this, 'top.add', '', '12', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num12">12</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
#
# 	                  			<span class="rank keep"><span class="blind">유지</span><em></em></span>
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15159840/list/67096" onclick="clickcr(this, 'top.clip', '', '12', event)" title="임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대.."><tooltip>임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대..</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '12', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>488,790</span>
# 									<span class="like"><span class="blind">좋아요 수</span>30,652</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15791242/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '13', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_27/PHMDh_1600162404863goUxz_GIF/7e8d8587-f736-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_291/OZz0W_1600162404352vGYMc_JPEG/cover_cover_2020091502634_0_20200915183309213.jpg?type=f194_109_blend"
# ...
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num96">96</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
# 	                  			<span class="rank new"><em>NEW</em></span>
#
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15791457/list/67096" onclick="clickcr(this, 'top.clip', '', '96', event)" title="[날씨] 내일 전국 대부분 &#039;가을비&#039;…제주 최고 80㎜"><tooltip>[날씨] 내일 전국 대부분 &#039;가을비&#039;…제주 최고 80㎜</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/yonhapnewstv" onclick="clickcr(this, 'top.chtitle', '', '96', event)">연합뉴스TV</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>2,762</span>
# 									<span class="like"><span class="blind">좋아요 수</span>5</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15755682/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '97', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200914_183/ulmOM_1600036707367gktEj_GIF/d67eea95-f611-11ea-8ff9-b496915e8f64.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200914_6/6OPck_16000365871669m7GX_JPEG/20200914_lpga_fr_%C0%CC%B9%CC%B8%B2.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200914_6/6OPck_16000365871669m7GX_JPEG/20200914_lpga_fr_%C0%CC%B9%CC%B8%B2.jpg?type=f194_109_blend"
# 									 width="100%" alt="&#039;드라마틱한 역전 우승&#039; 15언더파 우승 이미림 HL [ANA 인스퍼레이션 FR]" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>6:43</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15755682" data-login="false" onclick="clickcr(this, 'top.add', '', '97', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num97">97</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
# 	                  			<span class="rank new"><em>NEW</em></span>
#
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15755682/list/67096" onclick="clickcr(this, 'top.clip', '', '97', event)" title="&#039;드라마틱한 역전 우승&#039; 15언더파 우승 이미림 HL [ANA 인스퍼레이션 FR]"><tooltip>&#039;드라마틱한 역전 우승&#039; 15언더파 우승 이미림 HL [ANA 인스퍼레이션 FR]</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/ladiesgolf" onclick="clickcr(this, 'top.chtitle', '', '97', event)">LPGA 네이버스포츠</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>123,352</span>
# 									<span class="like"><span class="blind">좋아요 수</span>927</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15687713/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '98', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200909_206/9f6uB_1599658530947Dnw2v_GIF/33762097-f2a0-11ea-a65d-b496915e8884.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200909_234/meXWb_1599658073829mjtJJ_JPEG/C202000051_3_202009091002470681.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200909_234/meXWb_1599658073829mjtJJ_JPEG/C202000051_3_202009091002470681.jpg?type=f194_109_blend"
# 									 width="100%" alt="조영남&amp;이찬원 딜라일라♪ 꿈에 그리던 듀엣❣" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>3:22</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15687713" data-login="false" onclick="clickcr(this, 'top.add', '', '98', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num98">98</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
# 	                  			<span class="rank down"><span class="blind">하락</span><em>4</em></span>
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15687713/list/67096" onclick="clickcr(this, 'top.clip', '', '98', event)" title="조영남&amp;이찬원 딜라일라♪ 꿈에 그리던 듀엣❣"><tooltip>조영남&amp;이찬원 딜라일라♪ 꿈에 그리던 듀엣❣</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/tvchosun.trotf4" onclick="clickcr(this, 'top.chtitle', '', '98', event)">뽕숭아학당</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>63,171</span>
# 									<span class="like"><span class="blind">좋아요 수</span>8,053</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15752322/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '99', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200914_20/UTHjL_1600018651708Vpoz6_GIF/3f4a2148-f5c0-11ea-bb7d-a0369ff96154.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200913_226/uejs8_1600006917700Jxim3_JPEG/02dee5d2-fb57-4e2d-85b1-b43d0a4c8d06.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200913_226/uejs8_1600006917700Jxim3_JPEG/02dee5d2-fb57-4e2d-85b1-b43d0a4c8d06.jpg?type=f194_109_blend"
# 									 width="100%" alt="[종국먹방♥] 김종국, 10년 만에 먹는 짜장 라면에 코 박고 흡입★" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>2:40</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15752322" data-login="false" onclick="clickcr(this, 'top.add', '', '99', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num99">99</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
# 	                  			<span class="rank new"><em>NEW</em></span>
#
#
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15752322/list/67096" onclick="clickcr(this, 'top.clip', '', '99', event)" title="[종국먹방♥] 김종국, 10년 만에 먹는 짜장 라면에 코 박고 흡입★"><tooltip>[종국먹방♥] 김종국, 10년 만에 먹는 짜장 라면에 코 박고 흡입★</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/sbs.woori" onclick="clickcr(this, 'top.chtitle', '', '99', event)">미운 우리 새끼</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>244,836</span>
# 									<span class="like"><span class="blind">좋아요 수</span>622</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 					<div class="cds">
# 						<div class="cds_type">
# 							<a href="https://tv.naver.com/v/15775348/list/67096" class="cds_thm" onclick="clickcr(this, 'top.clip', '', '100', event)"
# 							   data-anisrc="https://phinf.pstatic.net/tvcast/20200915_55/qTqVk_16000997394551KAId_GIF/9044aedb-f69d-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15">
# 								<span class="mask _top_ani_area"></span>
# 								<img src="https://phinf.pstatic.net/tvcast/20200915_236/7gMXO_1600096899281crX8r_JPEG/4bdd9e2b-c230-4c8b-91c5-85098c78e9c2.jpg?type=f194_109_blend"
# 									 data-src="https://phinf.pstatic.net/tvcast/20200915_236/7gMXO_1600096899281crX8r_JPEG/4bdd9e2b-c230-4c8b-91c5-85098c78e9c2.jpg?type=f194_109_blend"
# 									 width="100%" alt="송창의, 골댕이 메시와의 첫 만남에 눈 번쩍!" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"'>
# 								<img src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" class="_ani_img" width="100%" alt="임시 이미지">
# 								<!-- [D]담았을때 class="tk_b check" -->
# 								<span class="tm_b"><span class="blind">재생시간</span>2:59</span>
# 								<span class="btn_my _click" data-event="addWatchLater" data-clipno="15775348" data-login="false" onclick="clickcr(this, 'top.add', '', '100', '');">나중에 보기</span>
# 							</a>
# 							<!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# 							<span class="num num100">100</span>
# 							<!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
#
#
#
# 	                  			<span class="rank down"><span class="blind">하락</span><em>33</em></span>
#
#
# 							<dl class="cds_info">
# 								<dt class="title">
# 									<a href="https://tv.naver.com/v/15775348/list/67096" onclick="clickcr(this, 'top.clip', '', '100', event)" title="송창의, 골댕이 메시와의 첫 만남에 눈 번쩍!"><tooltip>송창의, 골댕이 메시와의 첫 만남에 눈 번쩍!</tooltip></a>
# 								</dt>
# 								<dd class="chn">
# 									<a href="https://tv.naver.com/sbs.dongsang2" onclick="clickcr(this, 'top.chtitle', '', '100', event)">동상이몽2_너는 내 운명</a>
# 								</dd>
# 								<dd class="meta">
# 									<span class="hit"><span class="blind">재생 수</span>30,215</span>
# 									<span class="like"><span class="blind">좋아요 수</span>91</span>
# 								</dd>
# 							</dl>
# 						</div>
# 					</div>
#
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	</div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<script type="text/javascript" src="/resources/release/js_v2/deploy/tvcast.pc.Top100.merge_20200910150919.js"></script>
#
#
#
#
# <script type="text/javascript">
# 	var nsc = "tvcast.top100";
# 	var ghtEnv = {
# 		serviceDomain : "https://tv.naver.com",
# 		likeItDomain : 'https://common.like.naver.com',
# 		likeItApiDomain : 'https://common.like.naver.com',
# 		isLogin : false
# 	};
#
# 	jQuery(window).on("load", function() {
# 		tvcast.pc.Gnb.init();
# 		tvcast.pc.Subscription.init();
# 		MyPage.initEvent();
# 		tvcast.pc.AnimateThumb = new tvcast.pc.AnimateThumb({"baseEl" : "container"});
# 	});
# </script>
#
#
#
# <div class="floating_top">
#     <iframe frameborder="0" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="TOP"></iframe>
#     <a href="/" class="btn btn_home" onclick="clickcr(this, 'mov.home', '', '', event)" title="홈">홈</a>
#     <a href="#" class="btn btn_top" onclick="goTop();clickcr(this, 'mov.top', '', '', event)" title="TOP">TOP</a>
# </div>
#
# <script>
#     function goTop(){
# 		window.scrollTo(0, 0);
# 		var topEl = document.getElementById('u_skip');
# 		if (topEl) {
# 			topEl.tabIndex = -1;
# 			topEl.focus();
# 			topEl.removeAttribute('tabIndex');
# 		}
#     }
# </script>
#
# </div>
#
#
#
#
#
# <div id="footer" style="padding-left: 180px;">
# <ul>
#     <li class="first"><a href="http://www.naver.com/rules/service.html" target="_blank" onClick="clickcr(this, 'fot.agreement', '', '', event);">이용약관</a></li>
#     <li><a href="http://www.naver.com/rules/privacy.html" target="_blank" onClick="clickcr(this, 'fot.privacy', '', '', event);">개인정보처리방침</a></li>
#     <li><a href="http://www.naver.com/rules/disclaimer.html" target="_blank" onClick="clickcr(this, 'fot.disclaimer', '', '', event);">책임의 한계와 법적고지</a></li>
#     <li><a href="https://help.naver.com/support/alias/navertv/navertv_home-PC.naver" target="_blank" onClick="clickcr(this, 'fot.helpdesk', '', '', event);">네이버TV 고객센터</a></li>
#     <li><a href="https://studio.tv.naver.com/join" target="_blank" onClick="clickcr(this, 'fot.chopen', '', '', event);">채널 만들기</a></li>
#     <li><a href="/n/policy" onClick="clickcr(this, 'fot.policy', '', '', event);">네이버TV 운영정책</a></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자에 있으며, 이를 무단으로 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <address>
#     <a href="http://www.naver.com" class="nhn" target="_blank" onClick="clickcr(this, 'fot.navercorp', '', '', event);">
#         <img src="https://ssl.pstatic.net/static/common/footer/ci_naver.png" width="63" height="11" alt="NAVER">
#     </a>
#     <em>Copyright ©</em>
#     <a href="https://www.navercorp.com" target="_blank" onClick="clickcr(this, 'fot.navercorp', '', '', event);">NAVER Corp.</a>
#     <span>All Rights Reserved.</span>
# </address>
#
# </div>
#
# <div class="dimd" id="layerDimd" style="display:none"></div>
#
# <script type="text/javascript">
# 	function redirectMobile() {
# 		setCookie("NTC_PC_MODE", "false");
# 		var sRedirectPcUrl = "";
#
# 		if (location.search === "") {
# 			sRedirectPcUrl = 'https://m.tv.naver.com'+ location.pathname;
# 		} else {
# 			sRedirectPcUrl = 'https://m.tv.naver.com' +
# 							  location.pathname +
# 	        				  location.search.split("&")[0];
# 		}
# 		location.href = sRedirectPcUrl;
# 	}
#
# 	function setCookie(name, value) {
# 		var domain = ".tv.naver.com";
# 		var path = "/";
# 		document.cookie = name + "=" + value + "; path=" + path + "; domain=" + domain;
#     }
#
# 	var TagAZ = {
# 		query: function (obj) {
# 			var q = "";
# 			if (obj) {
# 				q = "?";
# 				for (var key in obj) {
# 					q += key + "=" + obj[key] + "&";
# 				}
# 			}
# 			return q;
# 		},
# 		getPageName: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageName ? ghtEnv.pageName : "";
# 			}
# 			return "";
# 		},
# 		getPageContentsId: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageContentsId ? ghtEnv.pageContentsId : "";
# 			}
# 			return "";
# 		},
# 		url: function(obj) {
# 			if(obj.href) {
# 				return obj.href;
# 			}
# 			return "";
# 		},
# 		send: function (r) {
# 			var sReq =r;
# 			var oImg = new Image();
# 			oImg.src = sReq;
# 		},
# 		tagClickEncoded : function (tagName, pageId, contentId) {
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		tagClick : function(tagName, pageId, contentId) {
# 			tagName = encodeURIComponent(tagName);
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		clicklog : function (tagName, pageId, contentId) {
# 			var obj = {
# 				a : nsc,
# 				c : contentId,
# 				d : location.href,
# 				f : (document.referrer ? document.referrer : ""),
# 				p : pageId,
# 				t : tagName, // tagName
#
# 			}
# 			var q = TagAZ.query(obj);
# 			TagAZ.send("/api/az/nc" + q);
# 		}
# 	};
#
# </script>
# </body>
# </html>

# %%
html=BeautifulSoup(raw.text,'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title id="headTitle">
#
#
#
#     		인기영상
#
#     </title>
# <meta charset="utf-8"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex" name="robots"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="100012287952710" property="fb:admins">
# <meta content="232491033870086" property="fb:app_id">
# <meta content="https://tv.naver.com/r/" property="og:url"/>
# <meta content="Top100 : 네이버TV" property="og:title"/>
# <meta content="동영상을 감상하는 가장 쉽고 빠른 방법" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://ssl.pstatic.net/img.tvcast/common/img/og/180629/OG_Tag_270_270.png" property="og:image"/>
# <link href="/resources/release/css/tvcast_20200910150919.css" rel="stylesheet" type="text/css"/>
# <link href="/resources/release/css/contest_20200910150919.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/jQuery.1.11.3.min.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/jQuery.cookie.1.4.1.min.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/img.tvcast/pc/js/eg/eg.1.3.0.pkgd.min.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/img.tvcast/pc/js/jQuery/perfect-scrollbar.jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#         jQuery.noConflict();
#
#         jQuery.cookie.defaults.path = '/';
#
#         jQuery.ajaxSetup({
#             cache: true
#         });
#     </script>
# <script src="/resources/release/js_v2/clickcr_20200910150919.js" type="text/javascript"></script>
# <script src="/resources/release/js_v2/tvcast.Common_20200910150919.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.web.sdk.js"></script>
# <link href="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.adplayer.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/tveta/libs/ssp_video/ssp.nonlinear.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#     <script type="text/javascript" src='/resources/release/js_v2/respond/respond.src_20200910150919.js'></script>
#     <![endif]-->
# </meta></meta></head>
# <body class="">
# <div id="u_skip">
# <a href="#aside" onclick="document.getElementById('aside').tabIndex=-1;document.getElementById('aside').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#container" id="gnb_goContent" onclick="document.getElementById('container').tabIndex=-1;document.getElementById('container').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="wrap">
# <!--[if lt IE 9]>
#
# <div class="notice_bnr" id="notice_bnr">
# 	<strong class="txt_notice">지금 사용중인 브라우저는 7월 이후 동영상 재생이 불가능합니다. 빠르고 안전한 <a href="https://whale.naver.com/ko/" target="_blank" class="link_whale" onclick="clickcr(this, 'STA.whaledown', '','');"><img src="https://ssl.pstatic.net/static/tv/navertv/pc/img/img_whale.png" width="28" height="20" alt="" class="icon_whale">네이버 웨일</a>로 업데이트 하세요!</strong>
# 	<a href="https://help.naver.com/support/contents/contents.help?serviceNo=3609&categoryNo=22360" target="_blank" class="link_notice" onclick="clickcr(this, 'STA.help', '','');">도움말 보기 <img src="https://ssl.pstatic.net/static/tv/navertv/pc/img/top_notice_arr.png" width="6" height="10" alt="" class="icon_arr"></a>
# </div>
#
# <![endif]-->
# <div id="header">
# <iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:60px;border:none;vertical-align:bottom" title="빈 프레임"></iframe>
# <div class="header_wrap">
# <div class="header_content">
# <h1 class="head_logo">
# <a class="logo_navertv" href="https://tv.naver.com">
# <span class="blind">네이버 TV</span>
# </a>
# </h1>
# <div class="head_search">
# <div class="search _searchAutoComplete" id="searchBoxWrapper">
# <form id="searchForm">
# <fieldset>
# <legend>검색</legend>
# <div class="input_wrap">
# <span class="ipt_srch">
# <label class="blind" for="searchQuery">검색어를 입력하세요.</label>
# <input autocomplete="off" class="" id="searchQuery" name="query" placeholder="검색어를 입력하세요" style="width:100%" title="검색어를 입력하세요" type="text" value=""/>
# <span class="auto_tx"><a class="_autoTxLink _toggle_btn" href="#" onclick="return false;"><img alt="자동완성 펼치기" class="_arrow" height="5" id="acButton" src="https://ssl.pstatic.net/static/tv/navertv/pc/img/icon_searchbar_arr_down.png" width="8"/></a></span>
# </span>
# <a class="btn_search" href="javascript:;" id="searchButton" title="검색">검색</a>
# <div class="auto_tx_area ly_atcmp wrap _suggestView" id="acView" style="display:none;">
# <iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="검색 폼"></iframe>
# <div class="wrap_recent_search" id="recentKeywordView" style="display:none">
# <div class="recent_search_header">
# <p class="tit">최근 검색어</p>
# </div>
# <ul class="list_recent_search _resentSearchBox" id="recentResultBox" style="display:block">
# <li data-keyword="@inKeyword@" data-order="@order@" data-search-type="recent">
# <a class="recent_keyword" href="javascript:void(0)" onclick="clickcr(this, 'STA.searchrecent', '', '', event)">
# <span class="recent_keyword_txt">@keyword@</span>
# </a>
# <a class="btn_del_keyword _recentKeywordDeleteBtn" href="javascript:void(0)">
# <span class="blind">삭제</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="auto_txt words _resultArea" id="autocompleteView" style="display:none">
# <ul class="_resultBox">
# <li data-search_type="not used">
# <a class="atcmp_keyword" href="javascript:void(0);">
# <span class="atcmp_keyword_img">@imageTag@</span>
# <span class="atcmp_keyword_txt">@txt@</span>
# </a>
# </li>
# </ul>
# <ul class="_resultBox list_keyword_hash">
# <li data-search-type="tag" data-txt="@in_txt@">
# <a class="atcmp_keyword" href="javascript:void(0);">
# <span class="atcmp_keyword_hash"><span class="blind">#</span></span>
# <span class="atcmp_keyword_txt">@txt@</span>
# </a>
# </li>
# </ul>
# <ul class="_resultBox list_keyword_ch">
# <li data-display-channel-id="@linkUrl@" data-search-type="channel" data-txt="@in_txt@">
# <a class="atcmp_keyword" href="javascript:void(0);">
# <span class="atcmp_keyword_img">@imageTag@</span>
# <span class="atcmp_keyword_txt">@txt@</span>
# </a>
# </li>
# </ul>
# </div>
# <p class="at_alert _alert" id="autocompleteAlertView" style="display:none;top:578px">자동완성 기능이 활성화되었습니다.</p>
# <div class="auto_tx_foorer _footer" id="autocompleteAllView">
# <a class="all_result _search" href="#" id="searchButtonAll" onclick="return false;">전체 검색 결과보기</a>
# <p class="auto_tx_etc">
# <a class="clse _unuse_btn" href="#" onclick="return false;">자동완성 끄기</a>
# </p>
# <img alt="기능을 다시 켤 때는 자동완성 펼치기를 선택하세요." class="help _use_guide" height="28" src="https://ssl.pstatic.net/img.tvcast/pc/img/img_atcmp.png" style="display:none;position:absolute;bottom:25px;right:4px" width="268"/>
# </div>
# </div>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="gnb_wrap">
# <a aria-label="Creator Studio 바로가기" class="btn_gnb btn_cs" href="https://studio.tv.naver.com" onclick="clickcr(this, 'STA.studio', '', '');"></a>
# <a aria-label="동영상 업로드" class="btn_gnb btn_upload" href="https://studio.tv.naver.com/clip/register" onclick="clickcr(this, 'STA.upload', '', '');"></a>
# <div class="gnb_my" id="gnb">
# <a class="btn_gnb btn_login _btnLogin" href="https://nid.naver.com/nidlogin.login" onclick="clickcr(this, 'STA.login', '', '');">로그인</a>
# <a aria-expanded="false" aria-haspopup="true" aria-label="나의 메뉴 보기" class="btn_mymenu _btnMyMenu" href="#" role="button" style="display: none;">
# <img alt="프로필 사진" class="_btnMyMenuImg" height="28" src="https://ssl.pstatic.net/static/common/myarea/myInfo.gif" width="28"/>
# </a>
# <div class="layer_mymenu _layerMyMenu">
# <div class="mychannel_none">
# <p class="guide">
# 										보유하고 있는 채널이 없습니다. <br/>
# 										지금 채널을 만들어 보세요.
# 									</p>
# <a class="link" href="https://studio.tv.naver.com/channel/register" onclick="clickcr(this, 'MYP.create', '', '');">채널 만들기</a>
# </div>
# <a class="btn_logout _btnLogOut" href="https://nid.naver.com/nidlogin.logout" onclick="clickcr(this, 'MYP.logout', '', '');" role="button">로그아웃</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	var ghtGnb = {
# 		sRequestUrl: 'https://ac.tv.naver.com/ac',
# 		sAutoCompleteV2: '/resources/release/js_v2/service_common/nautocomplete_20200910150919.js',
# 		sAutoCompleteV2View: '/resources/release/js_v2/service_common/tvcast.pc.SuggestView_20200910150919.js',
# 		sAutoTemplateImageTag: '<img src="https://phinf.pstatic.net/tvcast@emblemUrl@?type=round_31_31" onerror="this.src=\'https://phinf.pstatic.net/tvcast/20161227_13/photoinfra_1482831946369BANUd_PNG/default_round_ch.png?type=round_31_31\'" width="22" height="22" alt="임시 이미지">',
# 		bIsLogin : false
# 	};
# </script>
# <div class="side_menu" id="aside" role="navigation">
# <iframe frameborder="0" scrolling="no" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="빈 프레임"></iframe>
# <button aria-label="메뉴" aria-labelledby="asideToolTip" class="btn_aside" id="menuButton" type="button"></button>
# <div aria-hidden="false" class="aside_wrap _sideMenu">
# <div class="scrollbar" id="menuScrollBox">
# <ul class="list_snb _asideListSnb">
# <li class="snb_home _listSnbHome">
# <a class="link_snb" href="https://tv.naver.com/" onclick="clickcr(this, 'mnu.home', '', '', event)">
# <span class="icon icon_home"></span>
# <span class="title">홈</span>
# </a>
# </li>
# <li class="snb_popular _listSnbPopular">
# <a class="link_snb" href="https://tv.naver.com/r/" onclick="clickcr(this, 'mnu.popular', '', '', event)">
# <span class="icon icon_popular"></span>
# <span class="title">인기영상</span>
# </a>
# </li>
# <li class="snb_live _listSnbLive">
# <a class="link_snb" href="https://tv.naver.com/l/livehome" onclick="clickcr(this, 'mnu.livetb', '', '', event)">
# <span class="icon icon_live"></span>
# <span class="title">라이브<span class="icon_beta"><span class="blind">"beta"</span></span></span>
# </a>
# </li>
# <li class="snb_my _listSnbMy">
# <a class="link_snb" href="/my/playlist/?type=recent" onclick="clickcr(this, 'mnu.my', '', '', event)">
# <span class="icon icon_my"></span>
# <span class="title">MY</span>
# </a>
# <input aria-hidden="false" class="snb_toggle _snbToggle" data-toggletype="MY" id="subMenu1" name="subMenu" onclick="clickcr(this, 'mnu.mymore', '', '', event)" type="checkbox"/>
# <label aria-label="하위 메뉴 토글" class="btn_sub" for="subMenu1" role="button" tabindex="0"></label>
# <ul class="list_sub">
# <li class="_listSubMyRecent">
# <a class="menu_cnt" href="https://tv.naver.com/my/playlist/?type=recent" onclick="clickcr(this, 'mnu.watched', '', '', event)">최근 본 영상</a>
# </li>
# <li class="_listSubMyWatchlater">
# <a class="menu_cnt" href="https://tv.naver.com/my/playlist/?type=watch_later" onclick="clickcr(this, 'mnu.history', '', '', event)">나중에 볼 영상</a>
# </li>
# <li class="_listSubMyLikeit">
# <a class="menu_cnt" href="https://tv.naver.com/my/playlist/?type=likeit" onclick="clickcr(this, 'mnu.like', '', '', event)">좋아요 한 영상</a>
# </li>
# </ul>
# </li>
# <li class="snb_feed _listSnbFeed _myMenu" data-login="false" id="myArea">
# <a class="link_snb" href="https://tv.naver.com/my/subscription/updated" onclick="clickcr(this, 'mnu.feed', '', '', event)">
# <span class="icon icon_feed"></span>
# <span class="title">구독</span>
# </a>
# <p class="nolist">
# 			관심있는 채널을 구독하여<br/>업데이트 동영상을 받아보세요.
# 			<a class="btn_ch_search" href="/r/channel" onclick="clickcr(this, 'mnu.watch', '', '', event)">채널 탐색하기</a>
# </p>
# </li>
# <li class="snb_theme _listSnbTheme _exclusiveMenu" id="brandArea">
# <a class="link_snb" href="/p/class" onclick="clickcr(this, 'mnu.theme', '', '', event)">
# <span class="icon icon_theme"></span>
# <span class="title">테마</span>
# </a>
# <input aria-hidden="false" class="snb_toggle _snbToggle" data-toggletype="THEME" id="subMenu3" name="subMenu" onclick="clickcr(this, 'mnu.thememore', '', '', event)" type="checkbox"/>
# <label aria-label="하위 메뉴 토글" class="btn_sub" for="subMenu3" role="button" tabindex="0"></label>
# <ul class="list_sub _brand">
# </ul>
# <a class="btn_list_sub_more _click _exclusiveMenuFoldState" data-event="foldExclusiveMenu" href="#">더보기</a>
# </li>
# <li class="snb_broad _listSnbBrand" id="smrBrandArea">
# <a class="link_snb" href="/b/tvchosun" onclick="clickcr(this, 'mnu.media', '', '', event)">
# <span class="icon icon_broad"></span>
# <span class="title">방송관</span>
# </a>
# <input aria-hidden="false" class="snb_toggle _snbToggle" data-toggletype="BRAND" id="subMenu4" name="subMenu" onclick="clickcr(this, 'mnu.mediamore', '', '', event)" type="checkbox"/>
# <label aria-label="하위 메뉴 토글" class="btn_sub" for="subMenu4" role="button" tabindex="0"></label>
# <ul class="list_sub _smrBrand">
# </ul>
# </li>
# <li class="snb_etc _listSnbEtc">
# <ul class="list_sub">
# <li class="_listSubPatron">
# <a href="/special/patron" onclick="clickcr(this, 'mnu.patron', '', '', event)">후원하기<span class="icon_beta"><span class="blind">"beta"</span></span></a>
# </li>
# <li class="_listSubPlay">
# <a href="/play/" onclick="clickcr(this, 'mnu.playleague', '', '', event)">플레이리그</a>
# </li>
# <li class="_listSubNstore">
# <a href="http://serieson.naver.com/broadcasting/home.nhn" onclick="clickcr(this, 'mnu.tvlink', '', '', event)" target="_blank">방송 다시보기</a>
# </li>
# <li class="_listSubBlog">
# <a href="http://blog.naver.com/nv_tvcast" onclick="clickcr(this, 'mnu.attention', '', '', event)" target="_blank">공식블로그</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <ul aria-hidden="true" class="fold_snb _foldSnb">
# <li class="snb_home _listSnbHomeFold">
# <a aria-label="홈" class="link_snb" href="https://tv.naver.com/" onclick="clickcr(this, 'mnu.home', '', '', event)">
# <span class="icon icon_home"></span>
# </a>
# </li>
# <li class="snb_popular _listSnbPopularFold">
# <a aria-label="인기영상" class="link_snb" href="https://tv.naver.com/r/" onclick="clickcr(this, 'mnu.top100', '', '', event)">
# <span class="icon icon_popular"></span>
# </a>
# </li>
# <li class="snb_live _listSnbLiveFold">
# <a aria-label="라이브" class="link_snb" href="https://tv.naver.com/l/livehome" onclick="clickcr(this, 'mnu.livetb', '', '', event)">
# <span class="icon icon_live"></span>
# </a>
# </li>
# <li class="snb_my _listSnbMyFold">
# <a aria-label="MY" class="link_snb" href="/my/playlist/?type=recent" onclick="clickcr(this, 'mnu.my', '', '', event)">
# <span class="icon icon_my"></span>
# </a>
# </li>
# <li class="snb_feed _listSnbFeedFold">
# <a aria-label="구독" class="link_snb" href="https://tv.naver.com/my/subscription/updated" onclick="clickcr(this, 'mnu.update', '', '', event)">
# <span class="icon icon_feed"></span>
# </a>
# </li>
# <li class="snb_theme _listSnbThemeFold">
# <a aria-label="테마" class="link_snb" href="/p/class" onclick="clickcr(this, 'mnu.theme', '', '', event)">
# <span class="icon icon_theme"></span>
# </a>
# </li>
# </ul>
# </div>
# <div id="container">
# <div class="top100">
# <div class="cate_tit2">
# <div class="tit_wrap">
# <div class="tit_area">
# <h2><span>인기</span></h2>
# </div>
# <div class="cate_sort">
# <ul>
# <li class="on">
# <a href="https://tv.naver.com/r/" onclick="clickcr(this, 'tab.top100tab', '', '', event)">
# <span>TOP100</span>
# </a>
# </li>
# <li class="">
# <a href="https://tv.naver.com/i/" onclick="clickcr(this, 'tab.ntoptab', '', '', event)">
# <span>지금 뜨는</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="top_main">
# <div class="main_wrap">
# <div class="top_spot">
# <h2><span class="blind">네이버TV 인기</span></h2>
# <p class="noti">9.15 오후 3시 ~ 오후 4시 기준 (재생수, 재생시간)</p>
# <div class="top_flick">
# <ul class="rolling">
# <li>
# <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_123/lSRF6_16001413118660nyFj_GIF/152e147a-f705-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15781742/list/67096" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="[김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K" data-src="https://phinf.pstatic.net/tvcast/20200915_67/fiEik_1600141308919njf02_JPEG/CA202009150029.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_67/fiEik_1600141308919njf02_JPEG/CA202009150029.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>16:51</em>
# <span class="btn_my _click" data-clipno="15781742" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '1', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num1">1</span>
# <span class="rank keep"><span class="blind">유지</span><em></em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15781742" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>[김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/mbc.kimkwanghyun" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">김광현 (세인트루이스 카디널스)</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>97,894</span>
# <span class="like"><span class="blind">좋아요 수</span>785</span>
# </dd>
# </dl>
# </div>
# </div>
# </li>
# <li>
# <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_31/fIncv_1600099897447iGs2e_GIF/d919e504-f69e-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15775430/list/67096" onclick="clickcr(this, 'top.3clip', '', '2', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="박성광×이솔이, 서로 다른 취미 생활 즐기는 법!" data-src="https://phinf.pstatic.net/tvcast/20200915_55/M1wBY_1600097512029ptUCz_JPEG/af2ddce4-394e-4a82-a6a8-a2903293dd72.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_55/M1wBY_1600097512029ptUCz_JPEG/af2ddce4-394e-4a82-a6a8-a2903293dd72.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>2:59</em>
# <span class="btn_my _click" data-clipno="15775430" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '2', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num2">2</span>
# <span class="rank up"><span class="blind">상승</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15775430" onclick="clickcr(this, 'top.3clip', '', '2', event)">
# <strong class="tit"><span>박성광×이솔이, 서로 다른 취미 생활 즐기는 법!</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/sbs.dongsang2" onclick="clickcr(this, 'top.3chtitle', '', '2', event)">동상이몽2_너는 내 운명</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>238,347</span>
# <span class="like"><span class="blind">좋아요 수</span>384</span>
# </dd>
# </dl>
# </div>
# </div>
# </li>
# <li>
# <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_194/veCNV_16001458682989UCmy_GIF/f24bb78a-f70f-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15778620/list/67096" onclick="clickcr(this, 'top.3clip', '', '3', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="'Rookie of the year?' 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]" data-src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>10:41</em>
# <span class="btn_my _click" data-clipno="15778620" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '3', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num3">3</span>
# <span class="rank down"><span class="blind">하락</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15778620" onclick="clickcr(this, 'top.3clip', '', '3', event)">
# <strong class="tit"><span>'Rookie of the year?' 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/mbc.kimkwanghyun" onclick="clickcr(this, 'top.3chtitle', '', '3', event)">김광현 (세인트루이스 카디널스)</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>282,468</span>
# <span class="like"><span class="blind">좋아요 수</span>3,697</span>
# </dd>
# </dl>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="content">
# <div class="top100_mv">
# <div class="wrp_cds">
# <div class="cds_area">
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200424_14/fdxk0_1587654377208FB5tO_GIF/1dd3ae5f-856e-11ea-b412-b496915e8f50.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/13506302/list/67096" onclick="clickcr(this, 'top.clip', '', '4', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬" data-src="https://phinf.pstatic.net/tvcast/20200423_250/7RfxA_158765201233492bIr_JPEG/C202000040_3_202004231110485551.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200423_250/7RfxA_158765201233492bIr_JPEG/C202000040_3_202004231110485551.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>3:53</span>
# <span class="btn_my _click" data-clipno="13506302" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '4', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num4">4</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank keep"><span class="blind">유지</span><em></em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/13506302/list/67096" onclick="clickcr(this, 'top.clip', '', '4', event)" title="감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬"><tooltip>감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '4', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>737,358</span>
# <span class="like"><span class="blind">좋아요 수</span>32,183</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200622_78/tC2bL_1592785901711LCeGP_GIF/2d497aa2-b2e0-11ea-8648-a0369ff9072c.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/14391626/list/67096" onclick="clickcr(this, 'top.clip', '', '5', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="김호중 - 어느 60대 노부부의 이야기" data-src="https://phinf.pstatic.net/tvcast/20200622_220/uBlso_1592785900541gsL9T_PNG/eFT91uWEo87N.png?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200622_220/uBlso_1592785900541gsL9T_PNG/eFT91uWEo87N.png?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>6:13</span>
# <span class="btn_my _click" data-clipno="14391626" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '5', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num5">5</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>2</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/14391626/list/67096" onclick="clickcr(this, 'top.clip', '', '5', event)" title="김호중 - 어느 60대 노부부의 이야기"><tooltip>김호중 - 어느 60대 노부부의 이야기</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/satfreedom" onclick="clickcr(this, 'top.chtitle', '', '5', event)">불후의 명곡2 전설을 노래하다</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>889,515</span>
# <span class="like"><span class="blind">좋아요 수</span>32,329</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_233/jT54a_1600120299145y5b1A_GIF/7653bb9e-f6d4-11ea-8dce-a0369faad059.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15776974/list/67096" onclick="clickcr(this, 'top.clip', '', '6', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="1R 브라이튼 vs 첼시 경기 하이라이트" data-src="https://phinf.pstatic.net/tvcast/20200915_297/4XgUb_1600120128168YxIFN_JPEG/20200915_BRI_CHE_HL.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_297/4XgUb_1600120128168YxIFN_JPEG/20200915_BRI_CHE_HL.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>11:20</span>
# <span class="btn_my _click" data-clipno="15776974" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '6', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num6">6</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank keep"><span class="blind">유지</span><em></em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15776974/list/67096" onclick="clickcr(this, 'top.clip', '', '6', event)" title="1R 브라이튼 vs 첼시 경기 하이라이트"><tooltip>1R 브라이튼 vs 첼시 경기 하이라이트</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/eplnv" onclick="clickcr(this, 'top.chtitle', '', '6', event)">SPOTV_PL</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>126,697</span>
# <span class="like"><span class="blind">좋아요 수</span>351</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200914_166/sn4VS_1600088307922280r6_GIF/e5348c88-f689-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15773256/list/67096" onclick="clickcr(this, 'top.clip', '', '7', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="[단독] 신생아 거꾸로 들고 흔들…CCTV에 잡힌 학대" data-src="https://phinf.pstatic.net/tvcast/20200914_188/4JQai_16000883072416fK8w_JPEG/cover_0000841645_001_20200914215709448.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200914_188/4JQai_16000883072416fK8w_JPEG/cover_0000841645_001_20200914215709448.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>1:51</span>
# <span class="btn_my _click" data-clipno="15773256" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '7', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num7">7</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15773256/list/67096" onclick="clickcr(this, 'top.clip', '', '7', event)" title="[단독] 신생아 거꾸로 들고 흔들…CCTV에 잡힌 학대"><tooltip>[단독] 신생아 거꾸로 들고 흔들…CCTV에 잡힌 학대</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/sbsnews8" onclick="clickcr(this, 'top.chtitle', '', '7', event)">SBS뉴스</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>362,143</span>
# <span class="like"><span class="blind">좋아요 수</span>486</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_180/5wyDi_1600099922647hzpzS_GIF/6f9e5969-f6a0-11ea-b58f-246e963a3ab9.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15775522/list/67096" onclick="clickcr(this, 'top.clip', '', '8', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="박성광♥이솔이, 부부가 지혜롭게 사는 법!" data-src="https://phinf.pstatic.net/tvcast/20200915_40/YnjRP_1600098099897NKAT4_JPEG/e3d48803-266d-4e07-9a3b-0415a7308e46.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_40/YnjRP_1600098099897NKAT4_JPEG/e3d48803-266d-4e07-9a3b-0415a7308e46.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>3:26</span>
# <span class="btn_my _click" data-clipno="15775522" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '8', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num8">8</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>3</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15775522/list/67096" onclick="clickcr(this, 'top.clip', '', '8', event)" title="박성광♥이솔이, 부부가 지혜롭게 사는 법!"><tooltip>박성광♥이솔이, 부부가 지혜롭게 사는 법!</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/sbs.dongsang2" onclick="clickcr(this, 'top.chtitle', '', '8', event)">동상이몽2_너는 내 운명</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>64,407</span>
# <span class="like"><span class="blind">좋아요 수</span>162</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_5/e65qe_160013928181755PFO_GIF/893e1817-f700-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15781126/list/67096" onclick="clickcr(this, 'top.clip', '', '9', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)" data-src="https://phinf.pstatic.net/tvcast/20200915_133/evtTk_1600139278456sD1Ep_JPEG/CA202009150027.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_133/evtTk_1600139278456sD1Ep_JPEG/CA202009150027.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>16:02</span>
# <span class="btn_my _click" data-clipno="15781126" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '9', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num9">9</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>3</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15781126/list/67096" onclick="clickcr(this, 'top.clip', '', '9', event)" title="세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)"><tooltip>세인트루이스 vs 밀워키 DH1 H/L (2020.09.15)</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/mbc.MSPNEWS009" onclick="clickcr(this, 'top.chtitle', '', '9', event)">MLB 핫클립</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>30,125</span>
# <span class="like"><span class="blind">좋아요 수</span>105</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200911_28/gYiRO_1599758167542sKXly_GIF/018dabdc-f37b-11ea-a544-a0369ff969f4.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15709947/list/67096" onclick="clickcr(this, 'top.clip', '', '10', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬" data-src="https://phinf.pstatic.net/tvcast/20200911_63/XUUX3_1599752212071xiQvI_JPEG/C202000040_3_202009101111372471.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200911_63/XUUX3_1599752212071xiQvI_JPEG/C202000040_3_202009101111372471.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>3:48</span>
# <span class="btn_my _click" data-clipno="15709947" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '10', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num10">10</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>3</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15709947/list/67096" onclick="clickcr(this, 'top.clip', '', '10', event)" title="빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬"><tooltip>빈티지 목소리의 주인공 이찬원👍 ‘님은 먼 곳에’♬</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '10', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>117,611</span>
# <span class="like"><span class="blind">좋아요 수</span>10,913</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200914_123/mXQnP_1600092840941ExfM9_GIF/a78cde45-f68d-11ea-bf91-a0369fa46305.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15773758/list/67096" onclick="clickcr(this, 'top.clip', '', '11', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="#하이라이트#박보검X박소담_HOXY,이런게 삼귀는 건가요?" data-src="https://phinf.pstatic.net/tvcast/20200914_197/KDF2C_1600090019262RbwO9_JPEG/B120207900_EPI0003_23_B.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200914_197/KDF2C_1600090019262RbwO9_JPEG/B120207900_EPI0003_23_B.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>16:26</span>
# <span class="btn_my _click" data-clipno="15773758" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '11', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num11">11</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>25</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15773758/list/67096" onclick="clickcr(this, 'top.clip', '', '11', event)" title="#하이라이트#박보검X박소담_HOXY,이런게 삼귀는 건가요?"><tooltip>#하이라이트#박보검X박소담_HOXY,이런게 삼귀는 건가요?</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/cjenm.RecordOfYouth" onclick="clickcr(this, 'top.chtitle', '', '11', event)">청춘기록</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>50,335</span>
# <span class="like"><span class="blind">좋아요 수</span>1,226</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_300/4oqzV_16001443033751GaXr_GIF/7bf719a4-f705-11ea-ae86-b496915d8e58.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15781764/list/67096" onclick="clickcr(this, 'top.clip', '', '12', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="'빠던에 덕아웃 손가락질까지!' 커쇼 상대 홈런포, 그리샴의 도발" data-src="https://phinf.pstatic.net/tvcast/20200915_35/oLYF9_1600144302736oraCv_JPEG/CA202009150030_01.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_35/oLYF9_1600144302736oraCv_JPEG/CA202009150030_01.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>1:22</span>
# <span class="btn_my _click" data-clipno="15781764" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '12', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num12">12</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank down"><span class="blind">하락</span><em>7</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15781764/list/67096" onclick="clickcr(this, 'top.clip', '', '12', event)" title="'빠던에 덕아웃 손가락질까지!' 커쇼 상대 홈런포, 그리샴의 도발"><tooltip>'빠던에 덕아웃 손가락질까지!' 커쇼 상대 홈런포, 그리샴의 도발</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/mbc.MSPNEWS009" onclick="clickcr(this, 'top.chtitle', '', '12', event)">MLB 핫클립</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>79,282</span>
# <span class="like"><span class="blind">좋아요 수</span>237</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200806_146/c8eK4_159672506406193IrR_GIF/da9158b6-d7f1-11ea-b157-b496915d9eb0.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15159840/list/67096" onclick="clickcr(this, 'top.clip', '', '13', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대.." data-src="https://phinf.pstatic.net/tvcast/20200806_201/TaIl7_159672461283118w2G_JPEG/C202000040_3_202008061113453621.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200806_201/TaIl7_159672461283118w2G_JPEG/C202000040_3_202008061113453621.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>3:57</span>
# <span class="btn_my _click" data-clipno="15159840" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '13', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num13">13</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15159840/list/67096" onclick="clickcr(this, 'top.clip', '', '13', event)" title="임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대.."><tooltip>임영웅 ‘오래된 노래’ ♩ 추억을 떠오르게 한 무대..</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/tvchosun.lovecall" onclick="clickcr(this, 'top.chtitle', '', '13', event)">신청곡을 불러드립니다-사랑의 콜센타</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>487,163</span>
# <span class="like"><span class="blind">좋아요 수</span>30,602</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_295/njfiI_1600141354603J6h5y_GIF/7c467253-f705-11ea-b5e3-a0369ff96c40.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15781744/list/67096" onclick="clickcr(this, 'top.clip', '', '14', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="'광란의 질주' 포르쉐 미스터리…브레이크 안밟고 140km로 쾅쾅" data-src="https://phinf.pstatic.net/tvcast/20200915_254/CuotG_16001413142138pViX_JPEG/1600141269496.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_254/CuotG_16001413142138pViX_JPEG/1600141269496.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>2:15</span>
# <span class="btn_my _click" data-clipno="15781744" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '14', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num14">14</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank up"><span class="blind">상승</span><em>11</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15781744/list/67096" onclick="clickcr(this, 'top.clip', '', '14', event)" title="'광란의 질주' 포르쉐 미스터리…브레이크 안밟고 140km로 쾅쾅"><tooltip>'광란의 질주' 포르쉐 미스터리…브레이크 안밟고 140km로 쾅쾅</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/yonhapnews" onclick="clickcr(this, 'top.chtitle', '', '14', event)">연합뉴스</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>47,189</span>
# <span class="like"><span class="blind">좋아요 수</span>2</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_167/Sjd1v_1600137279186v2Hto_GIF/e8ed955a-f6fb-11ea-b5e3-a0369ff96c40.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15780434/list/67096" onclick="clickcr(this, 'top.clip', '', '15', event)">
# <span class="mask _top_ani_area"></span>
# <img alt='"담배 건강에 안 좋다" 직언에 바짝 언 김여정·맞장구 리설주' data-src="https://phinf.pstatic.net/tvcast/20200915_77/zDAuU_1600137278987D3Mr6_JPEG/cover_cover_202009151107095500_t_20200915113322570.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_77/zDAuU_1600137278987D3Mr6_JPEG/cover_cover_202009151107095500_t_20200915113322570.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>2:36</span>
# <span class="btn_my _click" data-clipno="15780434" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '15', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num15">15</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank keep"><span class="blind">유지</span><em></em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15780434/list/67096" onclick="clickcr(this, 'top.clip', '', '15', event)" title='"담배 건강에 안 좋다" 직언에 바짝 언 김여정·맞장구 리설주'><tooltip>"담배 건강에 안 좋다" 직언에 바짝 언 김여정·맞장구 리설주</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/ytnnews24" onclick="clickcr(this, 'top.chtitle', '', '15', event)">뉴스는 YTN</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>69,848</span>
# <span class="like"><span class="blind">좋아요 수</span>16</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_42/fhhEJ_1600148905382V1utj_GIF/0ffd7a31-f717-11ea-a65d-b496915e8884.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15784877/list/67096" onclick="clickcr(this, 'top.clip', '', '16', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="[영상] 김태년이 이렇게 말했으니...앞으로 군대 카톡 불나겠네" data-src="https://phinf.pstatic.net/tvcast/20200915_261/5cpfN_1600148904759HtUQb_JPEG/cover_cover_2020091501201_0_20200915144808685.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_261/5cpfN_1600148904759HtUQb_JPEG/cover_cover_2020091501201_0_20200915144808685.jpg?type=f194_109_blend" width="100%"/>
# ...
# 								keep : rank keep
# 							-->
# <span class="rank down"><span class="blind">하락</span><em>6</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15774501/list/67096" onclick="clickcr(this, 'top.clip', '', '95', event)" title="예수정, 김성철에 서령대 교수 자리 제안!"><tooltip>예수정, 김성철에 서령대 교수 자리 제안!</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/sbs.brahms" onclick="clickcr(this, 'top.chtitle', '', '95', event)">브람스를 좋아하세요?</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>32,902</span>
# <span class="like"><span class="blind">좋아요 수</span>304</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200901_193/4yoPW_1598947232436CU6jE_GIF/7cc789cd-ec28-11ea-afd4-a0369ff960ec.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15546852/list/67096" onclick="clickcr(this, 'top.clip', '', '96', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="여자가 남자에게 관심을 표현하는 방법 [리얼:타임:러브3] EP5" data-src="https://phinf.pstatic.net/tvcast/20200908_196/uZTof_15995347805545acuK_JPEG/1599534648666.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200908_196/uZTof_15995347805545acuK_JPEG/1599534648666.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>15:15</span>
# <span class="btn_my _click" data-clipno="15546852" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '96', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num96">96</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank down"><span class="blind">하락</span><em>8</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15546852/list/67096" onclick="clickcr(this, 'top.clip', '', '96', event)" title="여자가 남자에게 관심을 표현하는 방법 [리얼:타임:러브3] EP5"><tooltip>여자가 남자에게 관심을 표현하는 방법 [리얼:타임:러브3] EP5</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/whatwomenwant" onclick="clickcr(this, 'top.chtitle', '', '96', event)">킼TV</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>320,617</span>
# <span class="like"><span class="blind">좋아요 수</span>1,281</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_138/ziDLQ_1600143972061fsyKF_GIF/7ed4884e-f70b-11ea-90e5-246e963a3ee5.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15782819/list/67096" onclick="clickcr(this, 'top.clip', '', '97', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="해운대 '광란의 질주' 포르쉐…7중 추돌사고 블랙박스 영" data-src="https://phinf.pstatic.net/tvcast/20200915_278/cUnfh_1600143969185w2iq8_JPEG/1600143936366.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_278/cUnfh_1600143969185w2iq8_JPEG/1600143936366.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>1:05</span>
# <span class="btn_my _click" data-clipno="15782819" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '97', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num97">97</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank new"><em>NEW</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15782819/list/67096" onclick="clickcr(this, 'top.clip', '', '97', event)" title="해운대 '광란의 질주' 포르쉐…7중 추돌사고 블랙박스 영"><tooltip>해운대 '광란의 질주' 포르쉐…7중 추돌사고 블랙박스 영</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/news1noontv" onclick="clickcr(this, 'top.chtitle', '', '97', event)">[뉴스1] 눈TV</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>21,008</span>
# <span class="like"><span class="blind">좋아요 수</span>2</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_129/WGgxs_1600101776274eU9mA_GIF/10a39ca0-f691-11ea-ae86-b496915d8e58.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15774121/list/67096" onclick="clickcr(this, 'top.clip', '', '98', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="“좋대! 바이올린이” 이유진, 박은빈 때문에 연주자 포기한 사연 고백" data-src="https://phinf.pstatic.net/tvcast/20200915_208/MajL6_1600101775407pFYzS_JPEG/48266771-fb66-44cf-a7a3-1715f0adbee0.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_208/MajL6_1600101775407pFYzS_JPEG/48266771-fb66-44cf-a7a3-1715f0adbee0.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>2:47</span>
# <span class="btn_my _click" data-clipno="15774121" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '98', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num98">98</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank new"><em>NEW</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15774121/list/67096" onclick="clickcr(this, 'top.clip', '', '98', event)" title="“좋대! 바이올린이” 이유진, 박은빈 때문에 연주자 포기한 사연 고백"><tooltip>“좋대! 바이올린이” 이유진, 박은빈 때문에 연주자 포기한 사연 고백</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/sbs.brahms" onclick="clickcr(this, 'top.chtitle', '', '98', event)">브람스를 좋아하세요?</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>43,674</span>
# <span class="like"><span class="blind">좋아요 수</span>428</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200912_160/LdWKe_1599911542588bHQBJ_GIF/8737070e-f4e5-11ea-a56a-a0369ff968ac.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15738615/list/67096" onclick="clickcr(this, 'top.clip', '', '99', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="박서진 - 우연히" data-src="https://phinf.pstatic.net/tvcast/20200912_24/8Znzf_15999082097317TWpH_JPEG/5f5c9f9c59137d785f17a77e_upload_1599907845043.jpeg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200912_24/8Znzf_15999082097317TWpH_JPEG/5f5c9f9c59137d785f17a77e_upload_1599907845043.jpeg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>5:00</span>
# <span class="btn_my _click" data-clipno="15738615" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '99', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num99">99</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank down"><span class="blind">하락</span><em>25</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15738615/list/67096" onclick="clickcr(this, 'top.clip', '', '99', event)" title="박서진 - 우연히"><tooltip>박서진 - 우연히</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/satfreedom" onclick="clickcr(this, 'top.chtitle', '', '99', event)">불후의 명곡2 전설을 노래하다</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>19,493</span>
# <span class="like"><span class="blind">좋아요 수</span>1,639</span>
# </dd>
# </dl>
# </div>
# </div>
# <div class="cds">
# <div class="cds_type">
# <a class="cds_thm" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_128/gcWOB_1600125176350P3Tcc_GIF/bfc526cb-f6df-11ea-ae86-b496915d8e58.gif?type=mfullfill_234_132_ani_limit15" href="https://tv.naver.com/v/15777390/list/67096" onclick="clickcr(this, 'top.clip', '', '100', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="'K 본능까지 살아났다' 메이저리그 한 경기 최다 탈삼진을 기록하는 김광현 [5회말 H/L]" data-src="https://phinf.pstatic.net/tvcast/20200915_82/f99ix_1600125173353cd48p_JPEG/CA202009150014.jpg?type=f194_109_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200915_82/f99ix_1600125173353cd48p_JPEG/CA202009150014.jpg?type=f194_109_blend" width="100%"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0" width="100%"/>
# <!-- [D]담았을때 class="tk_b check" -->
# <span class="tm_b"><span class="blind">재생시간</span>1:49</span>
# <span class="btn_my _click" data-clipno="15777390" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.add', '', '100', '');">나중에 보기</span>
# </a>
# <!--
# 								[D]랭킹 숫자
# 								num1 : 1
# 								num2 : 2
# 								num3 : 3
# 								...
# 								num100 : 100
# 							-->
# <span class="num num100">100</span>
# <!--
# 								[D]순위
# 								up : rank up
# 								down : rank down
# 								new : rank new
# 								keep : rank keep
# 							-->
# <span class="rank down"><span class="blind">하락</span><em>25</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15777390/list/67096" onclick="clickcr(this, 'top.clip', '', '100', event)" title="'K 본능까지 살아났다' 메이저리그 한 경기 최다 탈삼진을 기록하는 김광현 [5회말 H/L]"><tooltip>'K 본능까지 살아났다' 메이저리그 한 경기 최다 탈삼진을 기록하는 김광현 [5회말 H/L]</tooltip></a>
# </dt>
# <dd class="chn">
# <a href="https://tv.naver.com/mbc.kimkwanghyun" onclick="clickcr(this, 'top.chtitle', '', '100', event)">김광현 (세인트루이스 카디널스)</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>96,763</span>
# <span class="like"><span class="blind">좋아요 수</span>813</span>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script src="/resources/release/js_v2/deploy/tvcast.pc.Top100.merge_20200910150919.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var nsc = "tvcast.top100";
# 	var ghtEnv = {
# 		serviceDomain : "https://tv.naver.com",
# 		likeItDomain : 'https://common.like.naver.com',
# 		likeItApiDomain : 'https://common.like.naver.com',
# 		isLogin : false
# 	};
#
# 	jQuery(window).on("load", function() {
# 		tvcast.pc.Gnb.init();
# 		tvcast.pc.Subscription.init();
# 		MyPage.initEvent();
# 		tvcast.pc.AnimateThumb = new tvcast.pc.AnimateThumb({"baseEl" : "container"});
# 	});
# </script>
# <div class="floating_top">
# <iframe frameborder="0" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="TOP"></iframe>
# <a class="btn btn_home" href="/" onclick="clickcr(this, 'mov.home', '', '', event)" title="홈">홈</a>
# <a class="btn btn_top" href="#" onclick="goTop();clickcr(this, 'mov.top', '', '', event)" title="TOP">TOP</a>
# </div>
# <script>
#     function goTop(){
# 		window.scrollTo(0, 0);
# 		var topEl = document.getElementById('u_skip');
# 		if (topEl) {
# 			topEl.tabIndex = -1;
# 			topEl.focus();
# 			topEl.removeAttribute('tabIndex');
# 		}
#     }
# </script>
# </div>
# <div id="footer" style="padding-left: 180px;">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" onclick="clickcr(this, 'fot.agreement', '', '', event);" target="_blank">이용약관</a></li>
# <li><a href="http://www.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank">개인정보처리방침</a></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" onclick="clickcr(this, 'fot.disclaimer', '', '', event);" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/alias/navertv/navertv_home-PC.naver" onclick="clickcr(this, 'fot.helpdesk', '', '', event);" target="_blank">네이버TV 고객센터</a></li>
# <li><a href="https://studio.tv.naver.com/join" onclick="clickcr(this, 'fot.chopen', '', '', event);" target="_blank">채널 만들기</a></li>
# <li><a href="/n/policy" onclick="clickcr(this, 'fot.policy', '', '', event);">네이버TV 운영정책</a></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자에 있으며, 이를 무단으로 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <address>
# <a class="nhn" href="http://www.naver.com" onclick="clickcr(this, 'fot.navercorp', '', '', event);" target="_blank">
# <img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/common/footer/ci_naver.png" width="63"/>
# </a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com" onclick="clickcr(this, 'fot.navercorp', '', '', event);" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# <div class="dimd" id="layerDimd" style="display:none"></div>
# <script type="text/javascript">
# 	function redirectMobile() {
# 		setCookie("NTC_PC_MODE", "false");
# 		var sRedirectPcUrl = "";
#
# 		if (location.search === "") {
# 			sRedirectPcUrl = 'https://m.tv.naver.com'+ location.pathname;
# 		} else {
# 			sRedirectPcUrl = 'https://m.tv.naver.com' +
# 							  location.pathname +
# 	        				  location.search.split("&")[0];
# 		}
# 		location.href = sRedirectPcUrl;
# 	}
#
# 	function setCookie(name, value) {
# 		var domain = ".tv.naver.com";
# 		var path = "/";
# 		document.cookie = name + "=" + value + "; path=" + path + "; domain=" + domain;
#     }
#
# 	var TagAZ = {
# 		query: function (obj) {
# 			var q = "";
# 			if (obj) {
# 				q = "?";
# 				for (var key in obj) {
# 					q += key + "=" + obj[key] + "&";
# 				}
# 			}
# 			return q;
# 		},
# 		getPageName: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageName ? ghtEnv.pageName : "";
# 			}
# 			return "";
# 		},
# 		getPageContentsId: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageContentsId ? ghtEnv.pageContentsId : "";
# 			}
# 			return "";
# 		},
# 		url: function(obj) {
# 			if(obj.href) {
# 				return obj.href;
# 			}
# 			return "";
# 		},
# 		send: function (r) {
# 			var sReq =r;
# 			var oImg = new Image();
# 			oImg.src = sReq;
# 		},
# 		tagClickEncoded : function (tagName, pageId, contentId) {
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		tagClick : function(tagName, pageId, contentId) {
# 			tagName = encodeURIComponent(tagName);
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		clicklog : function (tagName, pageId, contentId) {
# 			var obj = {
# 				a : nsc,
# 				c : contentId,
# 				d : location.href,
# 				f : (document.referrer ? document.referrer : ""),
# 				p : pageId,
# 				t : tagName, // tagName
#
# 			}
# 			var q = TagAZ.query(obj);
# 			TagAZ.send("/api/az/nc" + q);
# 		}
# 	};
#
# </script>
# </body>
# </html>

# %% [markdown]
# <img src="image/13.png">

# %% [markdown]
# ### 선택자를 사용하려면 컴퓨터가 소스 코드로 인식해야 합니다!
# #### BeautifulSoup을 통해 Text를 html 태그 단위로 잘라줘서 소스 코드로 인식할 수 있음.

# %% [markdown]
# 컨테이너: div.inner <br>
# 제목: dt.title <br>
# 채널명: dd.chn <br>
# 재생 수: span.hit <br>
# 좋아요 수: span.like <br>

# %% [markdown]
# <img src="image/14.png">

# %%
#1.컨테이너 수집
cont=html.select("div.inner")
print(cont) #리스트 형태로 저장되어 있는 데이터
len(cont)
# Out:
# [<div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_123/lSRF6_16001413118660nyFj_GIF/152e147a-f705-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15781742/list/67096" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="[김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K" data-src="https://phinf.pstatic.net/tvcast/20200915_67/fiEik_1600141308919njf02_JPEG/CA202009150029.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_67/fiEik_1600141308919njf02_JPEG/CA202009150029.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>16:51</em>
# <span class="btn_my _click" data-clipno="15781742" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '1', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num1">1</span>
# <span class="rank keep"><span class="blind">유지</span><em></em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15781742" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>[김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/mbc.kimkwanghyun" onclick="clickcr(this, 'top.3chtitle', '', '1', event)">김광현 (세인트루이스 카디널스)</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>97,894</span>
# <span class="like"><span class="blind">좋아요 수</span>785</span>
# </dd>
# </dl>
# </div>
# </div>, <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_31/fIncv_1600099897447iGs2e_GIF/d919e504-f69e-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15775430/list/67096" onclick="clickcr(this, 'top.3clip', '', '2', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="박성광×이솔이, 서로 다른 취미 생활 즐기는 법!" data-src="https://phinf.pstatic.net/tvcast/20200915_55/M1wBY_1600097512029ptUCz_JPEG/af2ddce4-394e-4a82-a6a8-a2903293dd72.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_55/M1wBY_1600097512029ptUCz_JPEG/af2ddce4-394e-4a82-a6a8-a2903293dd72.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>2:59</em>
# <span class="btn_my _click" data-clipno="15775430" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '2', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num2">2</span>
# <span class="rank up"><span class="blind">상승</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15775430" onclick="clickcr(this, 'top.3clip', '', '2', event)">
# <strong class="tit"><span>박성광×이솔이, 서로 다른 취미 생활 즐기는 법!</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/sbs.dongsang2" onclick="clickcr(this, 'top.3chtitle', '', '2', event)">동상이몽2_너는 내 운명</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>238,347</span>
# <span class="like"><span class="blind">좋아요 수</span>384</span>
# </dd>
# </dl>
# </div>
# </div>, <div class="inner">
# <a class="box" data-anisrc="https://phinf.pstatic.net/tvcast/20200915_194/veCNV_16001458682989UCmy_GIF/f24bb78a-f70f-11ea-a65d-b496915e8884.gif?type=mfullfill_406_228_ani_limit15" href="https://tv.naver.com/v/15778620/list/67096" onclick="clickcr(this, 'top.3clip', '', '3', event)">
# <span class="mask _top_ani_area"></span>
# <img alt="'Rookie of the year?' 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]" data-src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f406_228"' src="https://phinf.pstatic.net/tvcast/20200915_92/A0mDh_1600132078677RKlpO_JPEG/CA202009150022.jpg?type=f406_228_blend"/>
# <img alt="임시 이미지" class="_ani_img" src="https://ssl.pstatic.net/img.tvcast/pc/img/bg_blank.png" style="position:absolute; left:0px; top:0px; opacity:0"/>
# <em class="time"><span class="blind">재생시간</span>10:41</em>
# <span class="btn_my _click" data-clipno="15778620" data-event="addWatchLater" data-login="false" onclick="clickcr(this, 'top.3add', '', '3', '');">담기</span>
# </a>
# <div class="info">
# <span class="num num3">3</span>
# <span class="rank down"><span class="blind">하락</span><em>1</em></span>
# <dl class="cds_info">
# <dt class="title">
# <a href="https://tv.naver.com/v/15778620" onclick="clickcr(this, 'top.3clip', '', '3', event)">
# <strong class="tit"><span>'Rookie of the year?' 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]</span></strong>
# </a>
# </dt>
# <dd class="chn">
# <a class="ch" href="https://tv.naver.com/mbc.kimkwanghyun" onclick="clickcr(this, 'top.3chtitle', '', '3', event)">김광현 (세인트루이스 카디널스)</a>
# </dd>
# <dd class="meta">
# <span class="hit"><span class="blind">재생 수</span>282,468</span>
# <span class="like"><span class="blind">좋아요 수</span>3,697</span>
# </dd>
# </dl>
# </div>
# </div>]
# 3

# %% [markdown]
# <img src="image/15.png">

# %%
#2 영상 데이터 수집
title=cont[0].select_one("dt.title")
print(title)
print(title.text)
# Out:
# <dt class="title">
# <a href="https://tv.naver.com/v/15781742" onclick="clickcr(this, 'top.3clip', '', '1', event)">
# <strong class="tit"><span>[김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K</span></strong>
# </a>
# </dt>
#
#
# [김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K

# %%
chn=cont[0].select_one("dd.chn")
hit=cont[0].select_one("span.hit")
like=cont[0].select_one("span.like")
print(chn.text.strip());print(hit.text.strip());print(like.text.strip())
# Out:
# 김광현 (세인트루이스 카디널스)
# 재생 수97,894
# 좋아요 수785

# %%
#반복하기
for con in cont:
    title=con.select_one("dt.title")
    chn=con.select_one("dd.chn")
    hit=con.select_one("span.hit")
    like=con.select_one("span.like")
    print(title.text.strip());print(chn.text.strip());print(hit.text.strip());print(like.text.strip());print("-"*70)
# Out:
# [김광현 REVIEW] '완벽한 '속구'제구'무브먼트'  김광현, 7이닝 무실점 6K
# 김광현 (세인트루이스 카디널스)
# 재생 수97,894
# 좋아요 수785
# ----------------------------------------------------------------------
# 박성광×이솔이, 서로 다른 취미 생활 즐기는 법!
# 동상이몽2_너는 내 운명
# 재생 수238,347
# 좋아요 수384
# ----------------------------------------------------------------------
# 'Rookie of the year?' 이보다 더 나을 수 없는 완벽한 복귀전 [김광현 H/L]
# 김광현 (세인트루이스 카디널스)
# 재생 수282,468
# 좋아요 수3,697
# ----------------------------------------------------------------------

# %% [markdown]
# #### 변수=open(파일이름,'오픈형식')
# open 함수를 사용하면 파일을 해당하는 형식으로 열어줍니다.
#
# |파일 오픈 형식|설명|
# |:---:|:---:|
# |w(write)|새로 파일을 쓸 때 사용합니다.|
# |r(read)|파일로부터 데이터를 읽고 싶을 떄 사용합니다.|
# |a(append)|파일에 데이터를 추가로 쓰고 싶을 때 사용합니다.|
#
# #### 파일 변수.close()
# 열린 파일을 닫습니다. 파일을 닫지 않으면 컴퓨터의 어딘가에 파일이 열린채로 유지됩니다.

# %%
#csv파일 형식으로 저장하기
f=open("navertv.csv","w")
f.write("제목,채널명,재생수,좋아요\n")

raw=requests.get("http://tv.naver.com/r/") 
html=BeautifulSoup(raw.text,'html.parser')

for con in cont:
    title=con.select_one("dt.title").text.strip().replace(",","")
    chn=con.select_one("dd.chn").text.strip().replace(",","")
    hit=con.select_one("span.hit").text.strip().replace(",","")[4:]
    like=con.select_one("span.like").text.strip().replace(",","")[5:]
    f.write(title+','+chn+','+hit+','+like+'\n')

f.close()

# %% [markdown]
# ### 데이터를 엑셀파일로 저장하기
# <img src="image/19.png">

# %%
pip install OpenPyXL
# Out:
# Requirement already satisfied: OpenPyXL in c:\anaconda\envs\jiwoo\lib\site-packages (3.0.5)
# Requirement already satisfied: jdcal in c:\anaconda\envs\jiwoo\lib\site-packages (from OpenPyXL) (1.4.1)
# Requirement already satisfied: et-xmlfile in c:\anaconda\envs\jiwoo\lib\site-packages (from OpenPyXL) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

# %% [markdown]
# <img src="image/20.png"> <br>
# Workbook: 엑셀파일 전체 작업공간, 엑셀파일 자체를 Workbook이라고 부릅니다. <br>
# Worksheet: 엑셀파일에서 단일 작업공간, 하나의 큰 표라고 생각할 수 있습니다. <br>
# Cell: 엑셀에서 데이터가 저장되어있는 가장 작은 공간입니다. <br>

# %% [markdown]
# 시트.append(리스트)함수를 사용하면, 시트의 데이터가 없는 가장 첫 줄에 데이터를 입력합니다. <br>
# 이때 append의 괄호 안에는 리스트를 넣어줍니다. 리스트 값의 구분에 따라 열이 구분되어 입력됩니다. <br>
# 데이터를 가장 쉽게 저장할 수 있는 방법 중 하나이기 때문에 앞으로 가장 많이 사용하게 될 OpenPyXL함수 입니다.

# %%
wb=openpyxl.Workbook() # 워크북(엑셀파일)을 새로 만듭니다.
sheet=wb.active # 현재 활성화된 시트를 선택합니다.
sheet.append(["제목","채널명","재생 수","좋아요 수"])
raw=requests.get("http://tv.naver.com/r/") 
html=BeautifulSoup(raw.text,'html.parser')

for con in cont:
    title=con.select_one("dt.title").text.strip()
    chn=con.select_one("dd.chn").text.strip()
    hit=con.select_one("span.hit").text.strip().replace(",","")[4:]
    like=con.select_one("span.like").text.strip().replace(",","")[5:]
    
    sheet.append([title,chn,hit,like])

wb.save("navertv.xlsx") # 워크북(엑셀파일)을 원하는 이름으로 저장합니다.

# %% [markdown]
# ## Stage3 - 네이버 뉴스기사 수집하기
# - 안티 크롤링과 회피방법
# - 네이버 뉴스 수집하기

# %% [markdown]
# **<a href="http://naver.com"> 네이버 </a> 를 클릭한 후 건국대학교를 검색해주세요!** <br>
# **건국대학교의 뉴스를 클릭하면 나오는 뉴스 기사들의 제목과 언론사의 이름을 수집하는 데이터 수집기를 만들어 보겠습니다!**

# %%
raw=requests.get("https://search.naver.com/search.naver?where=news&query=건국대학교")
html=BeautifulSoup(raw.text,'html.parser')

# %% [markdown]
# <img src="image/16.png"> <br> <br> <br>
# <img src="image/17.png">

# %%
raw = requests.get("https://search.naver.com/search.naver?where=news&query=건국대학교",
                   headers={'User-Agent':'Mozilla/5.0'}) 
# 기존 코드의 requests.get()함수 안에 headers={'User-Agent':'Mozilla/5.0'} 이라는 헤더값이 추가된 형태입니다. 
# Mozilla5.0은 웹브라우저를 만들기 위해 사용되는 기본적인 엔진이라고 생각하면 됩니다!
# headers를 통해 서버에 데이터를 요청하면서 웹브라우저에 대한 정보를 같이 전송하여 마치 웹브라우저를 통해 데이터를 요청하는 것처럼 보이게 합니다.
html = BeautifulSoup(raw.text, "html.parser")

# %% [markdown]
# <img src="image/18.png">

# %% [markdown]
# 컨테이너: <span style="color:white"> ul.type01 > li <br> </span>
# 제목: <span style="color:white"> a._sp_each_title <br> </span>
# 언론사: <span style="color:white"> span._sp_each_source <br> </span>

# %%
# 컨테이너 수집
arti=html.select("ul.type01 > li")
# 기사별 데이터 수집
# 수집 반복
for ar in arti:
    title=ar.select_one("a._sp_each_title").text
    source=ar.select_one("span._sp_each_source").text
    print(title,source)
# Out:
# [건국대학교 예술디자인대학 영상영화학과] 창조적 통합 교육으로 첨단 영상 ... 씨네21
# 우리 대학, 인재 이렇게 뽑는다! (2) 내일신문
# 고려사이버대학교 미래교육원, 아동영어 테솔 과정 4기 수강생 모집 중앙일보
# [에듀워치]성균관대 vs 서강대, 영어가 가른 수능최저 난도 비즈니스워치
# 고경표 "건국대 영화과 출신…류혜영·혜리·BTS 진과 동문" 아이뉴스24
# 건국대, 수시에서 65% 선발…학종 'KU자기추천' 모집인원 확대 뉴스1
# [기고] 차별금지법은 ‘민주공화국’의 초석이다/한상희 건국대 법학전문대학... 서울신문
# 건국대 “수시 학생부종합 면접평가 비대면 운영… 계열별 면접시간 달라 유의... 에듀동아
# [2021대입잣대] 논문실적 1위 서울대.. 연대 성대 고대 경희대 톱5 베리타스알파
# 나사렛대학교 평생교육원에서 마케팅전문가 김유수 소장과 온라인마케팅과정 ... 헤모필리아라이프

# %% [markdown]
# ## Stage4 - 여러페이지에서 데이터 수집하기

# %% [markdown]
# ### URL과 요청값 이해하기

# %% [markdown]
# <img src="image/19.jpg"> <br>
# **<span style="color:orange"> 홈페이지 주소</span> :페이지의 기본 주소입니다.** <br>
# **<span style="color:blue"> 요청값</span> : 요청값에 따라 페이지에 표시되는 내용이 바뀝니다.** <br>
# **<span style="color:red">?</span> : 요청값과 홈페이지 주소를 연결해줍니다.</span>** <br>

# %% [markdown]
# `where는 검색 결과의 구분, query는 검색어를 의미하는구나!` <br>
# 이런 요청값 규칙은 정해져있는 것이 아니라 웹페이지를 구현한 개발자의 임의로 결정되는 것이기 때문에 직접 웹페이지에서 다른 페이지로 이동하면서 규칙을 찾아내야만 합니다. <br>
# 요청값들은 &를 통해서 구분되어 있습니다! <br> <br>
#
# |where=카테고리|query=검색어|start=기사번호|
# |:---:|:---:|:---:|
# |해당하는 카테고리의 검색결과를 보여줍니다. |해당하는 검색어의 검색결과를 보여줍니다. |해당하는 기사번호의 기사부터 보여줍니다. |
# |where=news|query=건국대학교|start=11|

# %% [markdown]
# 네이버 뉴스 검색결과는 한페이지에 기사를 **10개씩** 보여줍니다. <br>
# 요청값을 **1,11,21...** 으로 증가시키면 원하는만큼 데이터를 수집할 수 있습니다.

# %%
wb=openpyxl.Workbook()
sheet=wb.active
sheet.append(["제목","언론사"])
for page in range(1,100,10):
    raw = requests.get("https://search.naver.com/search.naver?where=news&query=건국대학교&start="+str(page),
                   headers={'User-Agent':'Mozilla/5.0'}) 
    html = BeautifulSoup(raw.text, "html.parser")

    # 컨테이너 수집
    arti=html.select("ul.type01 > li")
    
    for ar in arti:
        title=ar.select_one("a._sp_each_title").text
        source=ar.select_one("span._sp_each_source").text
        sheet.append([title,source])
wb.save("navernews.xlsx")

# %%
#기존의 엑셀파일에 계속 정보를 입력하고 싶다면?
try: 
    wb=openpyxl.load_workbook("navernew.xlsx")
    sheet=wb.active
except:
    wb=openpyxl.Workbook()
    sheet=wb.active
    sheet.append(["제목","언론사"])

# %% [markdown]
# # Part3

# %% [markdown]
# ## Stage1 - 링크 안에서 데이터 수집하기
# * 태그와 속성 다시보기
# * 속성값을 통해 링크 주소 알아내기
# * 새로운 링크에서 데이터 수집하기 <br>
#
# 지금까지 데이터 수집은 한페이지에서만 데이터를 수집할 수 있었습니다. 이번 스테이지에서는 링크를 통해 연결된 페이지에서 데이터를 수집하는 방법에 대해 공부합니다. <br>
# 네이버 영화의 현재 상영영화 페이지(https://movie.naver.com/movie/running/current.nhn) 에서 영화리스트에서 영화제목을 클릭하면 연결되는 상세 페이지에서 영화에 대한 평점과 리뷰데이터를 수집하겠습니다.

# %% [markdown]
# ### 연결된 페이지로 이동하기
# #### Review: 태그와 속성
# 위에서 HTML문서를 구성하는 태그(tag)와 속성(attribute)에 대해서 공부했습니다.
# <img src="image/21.png">

# %%
wb=openpyxl.Workbook()
sheet=wb.active
sheet.append(["영화 제목","평점","리뷰"])

# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://movie.naver.com/movie/running/current.nhn",
                   headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movie = html.select("dl.lst_dsc")

for m in movie:
    # 영화별 데이터 수집하기
    title = m.select_one("dt.tit>a")
    url=title.attrs["href"]
    print("="*50)
    print(url)
    print("https://movie.naver.com"+url)
    
    each_raw=requests.get("https://movie.naver.com"+url, headers={'User-Agent':'Mozilla/5.0'})
    each_html=BeautifulSoup(each_raw.text,'html.parser')
    
    #: div.score_result>ul>li
    # 평점: div.star_score em
    # 리뷰: div.score_reple p
    
    reviews=each_html.select("div.score_result>ul>li")
    
    for r in reviews:
        stars=r.select_one("div.star_score em").text
        reple=r.select_one("div.score_reple p").text
        sheet.append([title.text,stars,reple])
        
wb.save("navermovies.xlsx")
# Out:
# ==================================================
# /movie/bi/mi/basic.nhn?code=190010
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=190010
# ==================================================
# /movie/bi/mi/basic.nhn?code=194644
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=194644
# ==================================================
# /movie/bi/mi/basic.nhn?code=179859
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=179859
# ==================================================
# /movie/bi/mi/basic.nhn?code=164299
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=164299
# ==================================================
# /movie/bi/mi/basic.nhn?code=189069
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189069
# ==================================================
# /movie/bi/mi/basic.nhn?code=183278
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183278
# ==================================================
# /movie/bi/mi/basic.nhn?code=195377
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195377
# ==================================================
# /movie/bi/mi/basic.nhn?code=183772
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183772
# ==================================================
# /movie/bi/mi/basic.nhn?code=182234
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=182234
# ==================================================
# /movie/bi/mi/basic.nhn?code=193330
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=193330
# ==================================================
# /movie/bi/mi/basic.nhn?code=80466
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=80466
# ==================================================
# /movie/bi/mi/basic.nhn?code=178687
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=178687
# ==================================================
# /movie/bi/mi/basic.nhn?code=189623
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189623
# ==================================================
# /movie/bi/mi/basic.nhn?code=195409
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195409
# ==================================================
# /movie/bi/mi/basic.nhn?code=193799
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=193799
# ==================================================
# /movie/bi/mi/basic.nhn?code=13636
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=13636
# ==================================================
# /movie/bi/mi/basic.nhn?code=182353
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=182353
# ==================================================
# /movie/bi/mi/basic.nhn?code=194313
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=194313
# ==================================================
# /movie/bi/mi/basic.nhn?code=190584
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=190584
# ==================================================
# /movie/bi/mi/basic.nhn?code=189373
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189373
# ==================================================
# /movie/bi/mi/basic.nhn?code=177608
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=177608
# ==================================================
# /movie/bi/mi/basic.nhn?code=183116
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183116
# ==================================================
# /movie/bi/mi/basic.nhn?code=192066
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=192066
# ==================================================
# /movie/bi/mi/basic.nhn?code=192612
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=192612
# ==================================================
# /movie/bi/mi/basic.nhn?code=31940
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=31940
# ==================================================
# /movie/bi/mi/basic.nhn?code=195425
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195425
# ==================================================
# /movie/bi/mi/basic.nhn?code=191642
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=191642
# ==================================================
# /movie/bi/mi/basic.nhn?code=67457
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=67457
# ==================================================
# /movie/bi/mi/basic.nhn?code=189618
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189618
# ==================================================
# /movie/bi/mi/basic.nhn?code=14448
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=14448
# ==================================================
# /movie/bi/mi/basic.nhn?code=195668
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195668
# ==================================================
# /movie/bi/mi/basic.nhn?code=178351
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=178351
# ==================================================
# /movie/bi/mi/basic.nhn?code=186487
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=186487
# ==================================================
# /movie/bi/mi/basic.nhn?code=185273
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185273
# ==================================================
# /movie/bi/mi/basic.nhn?code=31565
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=31565
# ==================================================
# /movie/bi/mi/basic.nhn?code=134824
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=134824
# ==================================================
# /movie/bi/mi/basic.nhn?code=195061
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195061
# ==================================================
# /movie/bi/mi/basic.nhn?code=160837
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=160837
# ==================================================
# /movie/bi/mi/basic.nhn?code=187981
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=187981
# ==================================================
# /movie/bi/mi/basic.nhn?code=10922
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10922
# ==================================================
# /movie/bi/mi/basic.nhn?code=134963
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=134963
# ==================================================
# /movie/bi/mi/basic.nhn?code=185917
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185917
# ==================================================
# /movie/bi/mi/basic.nhn?code=185150
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185150
# ==================================================
# /movie/bi/mi/basic.nhn?code=188178
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=188178
# ==================================================
# /movie/bi/mi/basic.nhn?code=185139
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185139
# ==================================================
# /movie/bi/mi/basic.nhn?code=167622
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=167622
# ==================================================
# /movie/bi/mi/basic.nhn?code=182042
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=182042
# ==================================================
# /movie/bi/mi/basic.nhn?code=185282
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185282
# ==================================================
# /movie/bi/mi/basic.nhn?code=179394
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=179394
# ==================================================
# /movie/bi/mi/basic.nhn?code=179307
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=179307
# ==================================================
# /movie/bi/mi/basic.nhn?code=85825
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=85825
# ==================================================
# /movie/bi/mi/basic.nhn?code=189624
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189624
# ==================================================
# /movie/bi/mi/basic.nhn?code=183429
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183429
# ==================================================
# /movie/bi/mi/basic.nhn?code=186348
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=186348
# ==================================================
# /movie/bi/mi/basic.nhn?code=183046
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183046
# ==================================================
# /movie/bi/mi/basic.nhn?code=190458
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=190458
# ==================================================
# /movie/bi/mi/basic.nhn?code=185269
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185269
# ==================================================
# /movie/bi/mi/basic.nhn?code=184859
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=184859
# ==================================================
# /movie/bi/mi/basic.nhn?code=179420
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=179420
# ==================================================
# /movie/bi/mi/basic.nhn?code=189463
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189463
# ==================================================
# /movie/bi/mi/basic.nhn?code=188030
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=188030
# ==================================================
# /movie/bi/mi/basic.nhn?code=185134
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185134
# ==================================================
# /movie/bi/mi/basic.nhn?code=195180
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=195180
# ==================================================
# /movie/bi/mi/basic.nhn?code=154964
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=154964
# ==================================================
# /movie/bi/mi/basic.nhn?code=144806
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=144806
# ==================================================
# /movie/bi/mi/basic.nhn?code=188162
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=188162
# ==================================================
# /movie/bi/mi/basic.nhn?code=70025
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=70025
# ==================================================
# /movie/bi/mi/basic.nhn?code=174294
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=174294
# ==================================================
# /movie/bi/mi/basic.nhn?code=189747
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189747
# ==================================================
# /movie/bi/mi/basic.nhn?code=186239
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=186239
# ==================================================
# /movie/bi/mi/basic.nhn?code=146504
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=146504
# ==================================================
# /movie/bi/mi/basic.nhn?code=179694
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=179694
# ==================================================
# /movie/bi/mi/basic.nhn?code=183658
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=183658
# ==================================================
# /movie/bi/mi/basic.nhn?code=53152
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=53152
# ==================================================
# /movie/bi/mi/basic.nhn?code=174830
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=174830
# ==================================================
# /movie/bi/mi/basic.nhn?code=182642
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=182642
# ==================================================
# /movie/bi/mi/basic.nhn?code=97612
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=97612
# ==================================================
# /movie/bi/mi/basic.nhn?code=104072
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=104072
# ==================================================
# /movie/bi/mi/basic.nhn?code=142691
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=142691
# ==================================================
# /movie/bi/mi/basic.nhn?code=66098
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=66098
# ==================================================
# /movie/bi/mi/basic.nhn?code=175481
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=175481
# ==================================================
# /movie/bi/mi/basic.nhn?code=96984
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=96984
# ==================================================
# /movie/bi/mi/basic.nhn?code=86335
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=86335
# ==================================================
# /movie/bi/mi/basic.nhn?code=154573
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=154573
# ==================================================
# /movie/bi/mi/basic.nhn?code=193329
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=193329
# ==================================================
# /movie/bi/mi/basic.nhn?code=10117
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10117
# ==================================================
# /movie/bi/mi/basic.nhn?code=158887
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=158887
# ==================================================
# /movie/bi/mi/basic.nhn?code=194294
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=194294
# ==================================================
# /movie/bi/mi/basic.nhn?code=162854
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=162854
# ==================================================
# /movie/bi/mi/basic.nhn?code=191143
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=191143
# ==================================================
# /movie/bi/mi/basic.nhn?code=10568
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10568
# ==================================================
# /movie/bi/mi/basic.nhn?code=171580
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=171580
# ==================================================
# /movie/bi/mi/basic.nhn?code=190355
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=190355
# ==================================================
# /movie/bi/mi/basic.nhn?code=83528
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=83528
# ==================================================
# /movie/bi/mi/basic.nhn?code=129045
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=129045
# ==================================================
# /movie/bi/mi/basic.nhn?code=143358
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=143358
# ==================================================
# /movie/bi/mi/basic.nhn?code=10173
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10173
# ==================================================
# /movie/bi/mi/basic.nhn?code=10323
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10323
# ==================================================
# /movie/bi/mi/basic.nhn?code=169647
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=169647
# ==================================================
# /movie/bi/mi/basic.nhn?code=61628
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=61628
# ==================================================
# /movie/bi/mi/basic.nhn?code=189633
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189633
# ==================================================
# /movie/bi/mi/basic.nhn?code=105389
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=105389
# ==================================================
# /movie/bi/mi/basic.nhn?code=182387
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=182387
# ==================================================
# /movie/bi/mi/basic.nhn?code=123053
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=123053
# ==================================================
# /movie/bi/mi/basic.nhn?code=17942
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=17942
# ==================================================
# /movie/bi/mi/basic.nhn?code=140199
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=140199
# ==================================================
# /movie/bi/mi/basic.nhn?code=174261
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=174261
# ==================================================
# /movie/bi/mi/basic.nhn?code=101962
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=101962
# ==================================================
# /movie/bi/mi/basic.nhn?code=127359
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=127359
# ==================================================
# /movie/bi/mi/basic.nhn?code=10710
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10710
# ==================================================
# /movie/bi/mi/basic.nhn?code=13314
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=13314
# ==================================================
# /movie/bi/mi/basic.nhn?code=189123
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=189123
# ==================================================
# /movie/bi/mi/basic.nhn?code=78726
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=78726
# ==================================================
# /movie/bi/mi/basic.nhn?code=155123
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=155123
# ==================================================
# /movie/bi/mi/basic.nhn?code=32588
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=32588
# ==================================================
# /movie/bi/mi/basic.nhn?code=185151
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=185151
# ==================================================
# /movie/bi/mi/basic.nhn?code=52515
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=52515
# ==================================================
# /movie/bi/mi/basic.nhn?code=180851
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=180851
# ==================================================
# /movie/bi/mi/basic.nhn?code=163671
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=163671
# ==================================================
# /movie/bi/mi/basic.nhn?code=10676
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=10676

# %% [markdown]
# ## Stage2 - 이미지 데이터 수집하기
# * img 태그의 src 복습하기
# * urlretrieve를 활용해서 이미지 파일 저장하기

# %%
# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://movie.naver.com/movie/running/current.nhn",
                   headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movie = html.select("dl.lst_dsc")

for m in movie:
    # 영화별 데이터 수집하기
    title = m.select_one("dt.tit>a")
    url=title.attrs["href"]
    #print("="*50)
    #print(url)
    #print("https://movie.naver.com"+url)
    
    each_raw=requests.get("https://movie.naver.com"+url, headers={'User-Agent':'Mozilla/5.0'})
    each_html=BeautifulSoup(each_raw.text,'html.parser')
    
    #포스터 선택자
    poster=each_html.select_one("div.mv_info_area div.poster >a>img")
    poster_src=poster.attrs["src"]
    # print(poster_src)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4b8ce83ba025> in <module>
#      20     #포스터 선택자
#      21     poster=each_html.select_one("div.mv_info_area div.poster >a>img")
# ---> 22     poster_src=poster.attrs["src"]
#      23     # print(poster_src)
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %% [markdown]
# ### 파이썬 기본 라이브러리 활용
# 이번에는 웹페이지 위의 데이터(이미지)를 그대로 다운받아야하기 때문에 새로운 라이브러리를 사용해야합니다.<br>
# 지금까지 우리가 사용한 requests, BeautifulSoup4, OpenPyXL과 같은 오픈소스 패키지는 별도의 설치가 필요한 파이썬 외부 라이브러리였습니다. <br>
# 하지만 사람들이 많이 사용하기 때문에 **별도의 설치가 필요없이** 파이썬에서 기본적으로 제공하는 내부 라이브러리도 있습니다.
# <img src="image/22.png">

# %%
from urllib.request import urlretrieve
# import ssl
# ssl._create_default_https_context=ssl.create_unverified_context 
#보안 정책을 회피하는 부분, 안되는 사람만 실행

src="https://movie-phinf.pstatic.net/20200728_86/15959209130236RePy_JPEG/movie_image.jpg?type=m203_290_2"
urlretrieve(src,"poster.png")
# Out:
# ('poster.png', <http.client.HTTPMessage at 0x236fe462048>)

# %%
# 웹페이지에서 소스코드를 가져와 BeautifulSoup으로 파싱
raw = requests.get("https://movie.naver.com/movie/running/current.nhn",
                   headers={'User-Agent':'Mozilla/5.0'})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movie = html.select("dl.lst_dsc")

for m in movie:
    # 영화별 데이터 수집하기
    title = m.select_one("dt.tit>a")
    url=title.attrs["href"]
    #print("="*50)
    #print(url)
    #print("https://movie.naver.com"+url)
    
    each_raw=requests.get("https://movie.naver.com"+url, headers={'User-Agent':'Mozilla/5.0'})
    each_html=BeautifulSoup(each_raw.text,'html.parser')
    
    try:
    #포스터 선택자
        poster=each_html.select_one("div.mv_info_area div.poster >a>img")
        poster_src=poster.attrs["src"]
        urlretrieve(poster_src,"poster/"+title.text[:2]+".png")
    except:
        continue

# %% [markdown]
# # Part4

# %% [markdown]
# ## Stage1 - requests로 수집할 수 없는 페이지
# - 정적페이지와 동적페이지 구분하기

# %% [markdown]
# 네이버 지도 (https://v4.map.naver.com/) 페이지에서 원하는 키워드(약국)를 검색한 후 가게이름 / 주소 / 전화번호를 수집해봅시다.
#
# - 컨테이너: div.lsnx
# - 가게이름: div.lsnx dt>a
# - 주소: div.lsnx dd.addr
# - 전화번호 수집: div.lsnx dd.tel

# %%
raw=requests.get("https://v4.map.naver.com/",headers={'User-Agent':'Mozilla/5.0'})
html=BeautifulSoup(raw.text,'html.parser')
store=html.select("div.lsnx")
print(store)
# Out:
# []

# %% [markdown]
# <img src="image/24.png">
# <img src="image/25.png">

# %% [markdown]
# ## Stage2 - 동적페이지를 수집하는 브라우저
# - 브라우저 자동화패키지 selenium 알아보기
# - selenium을 통해 동적페이지 데이터 수집하기
#
# <img src="image/26.png">

# %% [markdown]
# **web driver 설치**
#
# selenium은 진짜 웹브라우저를 켜서 데이터를 수집하기 때문에 일반적으로 사용하는 Chrome이 아니라 파이썬이 열 수 있는 Chrome을 설치해줘야 합니다.
# 다운로드 페이지(https://chromedriver.chromium.org/downloads) 에 접속해서 내 컴퓨터에 설치된 chrome과 같은 버전의 chromedriver를 다운받습니다.
# `Chrome 버전 확인 방법. chrome://settings/help (chrome으로 접속하세요)`

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\anaconda\envs\jiwoo\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\anaconda\envs\jiwoo\lib\site-packages (from selenium) (1.25.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
import time

#1. 웹드라이버 켜기
driver=webdriver.Chrome("./chromedriver")

#2. 네이버 지도 접속하기
driver.get("https://v4.map.naver.com/")
close=driver.find_element_by_css_selector("div#dday_popup button")
close.click()

#3. 검색창에 검색어 입력하기(검색창 선택자:input#search-input)
search_box=driver.find_element_by_css_selector("input#search-input")
search_box.send_keys("약국") #send_keys: 텍스트를 입력할 수 있는 공간에 키워드 전송

#4. 검색버튼 누르기
search_button=driver.find_element_by_css_selector("button.spm")
search_button.click()

#지연시간 주기
time.sleep(1)

#5. 검색 결과 확인하기
# 컨테이너: div.lsnx
# 가게이름: dt>a
# 주소: dd.addr
# 전화번호 수집: dd.tel
stores=driver.find_elements_by_css_selector("div.lsnx")
for s in stores:
    name=s.find_element_by_css_selector("dt>a").text
    addr=s.find_element_by_css_selector("dd.addr").text
    try:
        tel=s.find_element_by_css_selector("dd.tel").text
        print(name,addr,tel)
    except:
        print(name,addr)
# Out:
# 안데르센약국 경기도 수원시 영통구 동탄원천로881번길 58 106 지번 031-213-5405
# 우리들약국 경기도 수원시 영통구 효원로 387 풍성프라자 지번 031-215-7845
# 온누리새소망약국 경기도 수원시 영통구 효원로 381 새롬프라자16차 지번 031-217-6571
# 사랑약국 경기도 수원시 영통구 효원로 387 풍성프라자 지번 031-213-0095
# 한일약국 경기도 수원시 영통구 효원로 397 지번 031-217-6869
# 나은약국 경기도 수원시 영통구 효원로 363 매탄위브하늘채아파트 지번 031-217-7721
# 효원약국 경기도 수원시 영통구 동수원로 316 임광아파트상가 101호 지번 031-238-2996
# 화목약국 경기도 수원시 권선구 매탄로 11 관리실 및 노인정 지번 031-223-5949
# 권선중앙약국 경기도 수원시 권선구 동수원로242번길 27 지번 031-226-2326
# 보람약국 경기도 수원시 권선구 동수원로242번길 22 지번
