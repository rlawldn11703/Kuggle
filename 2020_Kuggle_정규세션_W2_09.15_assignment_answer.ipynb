# %% [markdown]
# # Part 1

# %% [markdown]
# ## Challenge1 - 간단한 웹페이지 만들어보기
# 2주차에 배운 태그와 속성을 이용해서 다음과 같은 간단한 웹페이지를 만들어 보세요!

# %% [markdown]
# <img src="image/6.png">

# %% [markdown]
# <h1>다음부터</h1>
# <h3>엄지용, 2014</h3>
#
# <img width="200px" src="이미지 소스">
#
# <br>
# 이번까지만 이렇게 하고<br>
# 다음부턴 이러지 말아야지<br>
#
# <br>
#
# 라며 버려버린 시간들이<br>
# 언젠간 한데 모여<br>
# <u>우린 뭐 <b>네 <a href="링크">인생</a> 아니었냐</b>고 따져 물어올 것만 같다.</u><br>
#
# <img width="100px" src="이미지소스2"><br>
# 시집을 받아보고 싶으면 메일주소를 써주세요!<br> <input type="text">

# %% [markdown]
# ## Challenge2 - 4위부터 100위까지의 영상 정보 선택하기
# 다음 순서에 맞게 4위부터 100위 영상의 제목, 채널명, 재생 수, 좋아요 수를 선택하는 선택자를 찾아봅시다.
# 1. 4 - 100위 영상을 포함하는 컨테이너 선택자 찾기 <br>
# ` 선택자 검증(검색)할 때 97개의 데이터가 나와야합니다 :) ` <br>
# 2. 제목, 채널명, 재생 수, 좋아요 수에 해당하는 선택자 찾기 <br>
# `Challenge를 통해 찾아낸 선택자는 3주차 데이터수집기 만들기 시간에 활용됩니다. 편한 방법으로 꼭 저장해주세요.`

# %% [markdown]
# 컨테이너: div.cds
# 제목: div.cdsdt.title
# 채널명: div.cdsdd.chn
# 재생 수: div.cdsspan.hit
# 좋아요 수: div.cdsspan.like

# %% [markdown]
# ## Homework1 -  Y-Combinator 스타트업 뉴스기사 가져오기
# Y-Combinator(https://news.ycombinator.com) 뉴스 페이지에 접속해서 아래 정보들을 가지고 있는 태그의 선택자를 찾아봅시다.
# 1. 컨테이너
# 2. 순위
# 3. 제목
# 4. 출처

# %% [markdown]
# 컨테이너: tr.athing
# 순위: tr.athingspan.rank
# 제목: tr.athinga.storylink
# 출처: tr.athingspan.sitebit

# %% [markdown]
# ## Homework2 - 네이버 시리즈 e북 인기 TOP100 데이터 가져오기
# 네이버 시리즈 e북 인기 TOP100 페이지에서(https://series.naver.com/ebook/top100List.nhn) 아래 데이터를 선택할 수 있는 컨테이너를 찾아봅니다.
# 1. 컨테이너
# 2. 제목
# 3. 저자

# %% [markdown]
# 컨테이너: div.lst_thum_wrap li
# 제목: div.lst_thum_wrap lia strong
# 저자: div.lst_thum_wrap lispan.writer

# %% [markdown]
# # Part2

# %% [markdown]
# ## Challenge1 - 4위에서 100위까지 데이터 수집하기

# %% [markdown]
# 앞에서 만든 데이터수집기 코드(1-3영상)에 4-100위 영상에 대한 제목, 채널이름, 재생수, 좋아요수를 수집하는 코드를 추가해서 1-100위 영상에 대한 데이터를 모두 출력하는 코드를 만들어봅시다.
# 1. 컨테이너 수집하기(97개; 4-100위)
# 2. 각 세부데이터 수집하기
# 3. 컨테이너 반복하며 수집하기
# 4. (선택)예쁘게 출력하기 <br>
# `Challenge를 통해 찾아낸 선택자는 3주차 데이터수집기 만들기 시간에 활용됩니다. 편한 방법으로 꼭 저장해주세요.`

# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get("https://tv.naver.com/r")
html = BeautifulSoup(raw.text, "html.parser")

# 1위 - 3위 컨테이너 선택자: div.inner
clips = html.select("div.inner")

for cl in clips:
    title = cl.select_one("dt.title")
    chn = cl.select_one("dd.chn")
    hit = cl.select_one("span.hit")
    like = cl.select_one("span.like")

    print("제목", title.text.strip())
    print("채널명", chn.text.strip())
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)


# 4위-100위 컨테이너 선택자: 
clips = html.select("div.cds")

for cl in clips:
    title = cl.select_one("dt.title")
    chn = cl.select_one("dd.chn")
    hit = cl.select_one("span.hit")
    like = cl.select_one("span.like")

    print("제목", title.text.strip())
    print("채널명", chn.text.strip())
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
# Out:
# 제목 강경준, 엄마 바라기♥정우에 섭섭한 초보 아빠!
# 채널명 동상이몽2_너는 내 운명
# 재생 수97,498
# 좋아요 수255
# ...
# 제목 김호중 - 어느 60대 노부부의 이야기
# 채널명 불후의 명곡2 전설을 노래하다
# 재생 수951,914
# 좋아요 수33,471
# ...
# 제목 임영웅 ‘옛사랑’ ♪ 감성 장인 히어로 💧
# 채널명 신청곡을 불러드립니다-사랑의 콜센타
# 재생 수879,997
# 좋아요 수34,965
# ...
# 제목 [단독 선공개] 박은빈의 바이올린 연주, 박지현의 평가는?!
# 채널명 브람스를 좋아하세요?
# 재생 수65,522
# 좋아요 수730
# ...
# 제목 장신영♥강경준, 상위 1퍼센트 정우 검사 결과에 충격!
# 채널명 동상이몽2_너는 내 운명
# 재생 수318,565
# 좋아요 수668
# ...
# 제목 완벽한 포물선! 아쉽게 골대를 맞는 이승우의 슈팅
# 채널명 해외축구 (SPOTV)
# 재생 수157,303
# 좋아요 수635
# ...
# 제목 [PL] '미친 화력 4골 폭발' 손흥민 S.햄튼전 활약상
# 채널명 SPORTSTIME (스포츠타임)
# 재생 수1,892,122
# 좋아요 수23,022
# ...
# 제목 5화#하이라이트#박보검 NO밀당 YES고백♡박소담X박보검 오늘부터 1일(?)
# 채널명 청춘기록
# 재생 수65,631
# 좋아요 수1,259
# ...
# 제목 [PL] '맨시티엔 역시 덕배' 케빈 데 브라위너 울버햄튼전 활약상
# 채널명 SPORTSTIME (스포츠타임)
# 재생 수54,967
# 좋아요 수240
# ...
# 제목 2R 사우스햄튼 vs 토트넘 경기 하이라이트
# 채널명 SPOTV_PL
# 재생 수637,034
# 좋아요 수4,816
# ...
# 제목 ※분노주의※ 17살 때 엄마에게 말 못 하고 집을 나오게 된 이유😢
# 채널명 무엇이든 물어보살
# 재생 수197,692
# 좋아요 수361
# ...
# 제목 2R 울버햄튼 vs 맨체스터 시티 경기 골모음
# 채널명 SPOTV_PL
# 재생 수62,930
# 좋아요 수269
# ...

# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get("https://tv.naver.com/r")
html = BeautifulSoup(raw.text, "html.parser")

# 1위 - 100위 컨테이너 선택자: dl.cds_info
clips = html.select("dl.cds_info")

for cl in clips:
    title = cl.select_one("dt.title")
    chn = cl.select_one("dd.chn")
    hit = cl.select_one("span.hit")
    like = cl.select_one("span.like")

    print("제목", title.text.strip())
    print("채널명", chn.text.strip())
    print(hit.text.strip())
    print(like.text.strip())
    print("="*50)
# Out:
# 제목 강경준, 엄마 바라기♥정우에 섭섭한 초보 아빠!
# 채널명 동상이몽2_너는 내 운명
# 재생 수94,672
# 좋아요 수253
# ...
# 제목 김호중 - 어느 60대 노부부의 이야기
# 채널명 불후의 명곡2 전설을 노래하다
# 재생 수951,781
# 좋아요 수33,472
# ...
# 제목 임영웅 ‘옛사랑’ ♪ 감성 장인 히어로 💧
# 채널명 신청곡을 불러드립니다-사랑의 콜센타
# 재생 수879,875
# 좋아요 수34,965
# ...
# 제목 [단독 선공개] 박은빈의 바이올린 연주, 박지현의 평가는?!
# 채널명 브람스를 좋아하세요?
# 재생 수62,885
# 좋아요 수723
# ...
# 제목 장신영♥강경준, 상위 1퍼센트 정우 검사 결과에 충격!
# 채널명 동상이몽2_너는 내 운명
# 재생 수317,332
# 좋아요 수667
# ...
# 제목 완벽한 포물선! 아쉽게 골대를 맞는 이승우의 슈팅
# 채널명 해외축구 (SPOTV)
# 재생 수154,259
# 좋아요 수630
# ...
# 제목 [PL] '미친 화력 4골 폭발' 손흥민 S.햄튼전 활약상
# 채널명 SPORTSTIME (스포츠타임)
# 재생 수1,891,602
# 좋아요 수23,020
# ...
# 제목 5화#하이라이트#박보검 NO밀당 YES고백♡박소담X박보검 오늘부터 1일(?)
# 채널명 청춘기록
# 재생 수64,245
# 좋아요 수1,253
# ...
# 제목 [PL] '맨시티엔 역시 덕배' 케빈 데 브라위너 울버햄튼전 활약상
# 채널명 SPORTSTIME (스포츠타임)
# 재생 수53,988
# 좋아요 수240
# ...
# 제목 2R 사우스햄튼 vs 토트넘 경기 하이라이트
# 채널명 SPOTV_PL
# 재생 수636,743
# 좋아요 수4,816
# ...
# 제목 ※분노주의※ 17살 때 엄마에게 말 못 하고 집을 나오게 된 이유😢
# 채널명 무엇이든 물어보살
# 재생 수197,335
# 좋아요 수361
# ...
# 제목 2R 울버햄튼 vs 맨체스터 시티 경기 골모음
# 채널명 SPOTV_PL
# 재생 수61,942
# 좋아요 수269
# ...

# %% [markdown]
# ## Challenge2 - Y-Combinator 뉴스기사 가져오기

# %% [markdown]
# 1주차 homework1에서 다뤘던 Y-Combinator 스타트업 뉴스기사(https://news.ycombinator.com) 에서 순위, 제목을 수집하는 파이썬 코드를 작성해봅니다. <br>
# URL 요청값 규칙도 직접찾아내서 1~3페이지까지 기사 페이지를 수집하는 수집기를 만들어 봅시다.
# 1. 컨테이너, 순위, 제목 선택자 찾기 - 1주차 homework1 참고
# 2. 페이지를 변환시키는 URL 요청값 규칙 찾기
# 3. 코딩을 통해 수집기 완성하기!

# %%
import requests
from bs4 import BeautifulSoup

# 1-3페이지 반복
for n in range(1, 4):
    # p=1, p=2, p=3으로 반복해준다.
    raw = requests.get("https://news.ycombinator.com/news?p="+str(n),
                       headers={"User-Agent":"Mozilla/5.0"})
    html = BeautifulSoup(raw.text, 'html.parser')

    articles = html.select("tr.athing")

    for ar in articles:
        rank = ar.select_one("span.rank").text
        title = ar.select_one("a.storylink").text

        print(rank, title)
# Out:
# 1. Indian robot climbs trees to harvest coconuts
# 2. Almost 90 percent of NYC bars and restaurants couldn’t pay August rent
# 3. Chrome Web Store payments deprecation
# 4. Why should I do production support?
# 5. New Steve Jobs recordings from the '80s released
# 6. Things we learned running Postgres 13
# 7. Microsoft to acquire ZeniMax Media and Bethesda Softworks for $7.5B
# 8. St Helena laws for inhabitants 1672
# 9. Noisefunge: A music programming environment in Befunge
# 10. When feature flags do and don’t make sense (2019)
# 11. The unrealized potential of federation
# 12. Star Tek–Exploiting the Final Frontier: Counterspace Operations in 2025 (1996) [pdf]
# 13. The Kivaloo Data Store
# 14. My least favorite Rust type
# 15. Pricing Low-Touch SaaS
# 16. Is revenue model more important than culture?
# 17. A Time Leap Challenge for Sat Solving
# 18. Flour Fixated
# 19. Cobaul: A COBOL to WebAssembly Compiler
# ...

# %% [markdown]
# ## Homework1 - 네이버 e북 인기 TOP100 데이터 수집
# 네이버 시리즈 e북 인기 TOP100 페이지에서(https://series.naver.com/ebook/top100List.nhn) 아래 데이터를 수집하는 코드를 만들어봅니다.
# 1. 컨테이너, 제목, 저자를 선택하는 선택자를 찾아냅니다.
# 2. 파이썬을 활용해서 데이터 수집기를 만들어냅니다.
# 3. (심화)1-20위, 21-40위, ... , 81-100위 서적을 모두 수집할 수 있는 요청값을 찾아 수집기를 만들어 냅니다.
# 4. 수집한 데이터를 원하는 방식으로 저장합니다. (csv, xlsx)

# %%
import requests
from bs4 import BeautifulSoup

for p in range(1, 6):
    raw = requests.get("https://series.naver.com/ebook/top100List.nhn?page="+str(p),
                       headers={"User-Agent":"Mozilla/5.0"})
    html = BeautifulSoup(raw.text, 'html.parser')

    books = html.select("div.lst_thum_wrap li")
    for b in books:
        title = b.select_one("a strong").text
        author = b.select_one("span.writer").text

        print(title, author)
# Out:
# 그림책 한 권의 힘 이현아
# 매우 예민한 사람들을 위한 책 전홍진
# 돈의 속성 김승호
# 보건교사 안은영 정세랑
# 어른의 어휘력 유선경
# 기분이 태도가 되지 않게 레몬심리, 박영란
# 한번도 경험해보지 못한 나라 강양구,권경애,김경율,서민,진중권
# 심판(양장본 HardCover) 베르나르 베르베르, 전미연
# 아몬드 손원평
# 미움받을 용기 기시미 이치로, 전경아
# 이유가 많으니 그냥이라고 할 수밖에 을냥이
# 이기적 유전자 리처드 도킨스, 홍영남,이상임
# 죽은 자의 집 청소 김완
# 살아가는 데 가장 많이 써먹는 심리학 지루징, 정유희
# 더 해빙 이서윤,홍주연
# 내가 예민한게 아니라 네가 너무한 거야 유은정
# 주가 급등 사유 없음 장지웅
# 소년이 온다 한강
# 주식 오로지 차트로만 수익내기 이윤
# 지쳤거나 좋아하는 게 없거나 글배우
# 세계미래보고서 2035-2055 박영숙,제롬 글렌
# 재무제표 모르면 주식투자 절대로 하지마라 사경인
# 힘든 시대를 위한 좋은 경제학 아브히지트 바네르지,에스테르 뒤플로, 김승진
# 내 인생의 첫 주식 공부 백영
# 무엇을 위해 살죠? 박진영
# 이토록 공부가 재미있어지는 순간 박성혁
# 전설로 떠나는 월가의 영웅 피터 린치,존 로스차일드, 이건
# 규칙 없음 리드 헤이스팅스,에린 마이어, 이경남
# 12가지 인생의 법칙 조던 B. 피터슨, 강주헌
# 슈퍼거미 김정환의 이기는 투자법 - 실전편 김정환
# 존리의 부자되기 습관 존 리
# 일본군 위안부, 또 하나의 목소리 배춘희,박유하
# 선물주는산타의 주식투자 시크릿 선물주는산타
# 자존감 수업 윤홍균
# 엘리어트 파동이론 R.N. Elliott
# 초집중 니르 이얄, 김고명
# 신경 끄기의 기술 마크 맨슨, 한재호
# 저는 주식투자가 처음인데요 강병욱
# 코로나 이후의 세계 제이슨 솅커, 박성현
# 저는 남자고, 페미니스트입니다 최승범
# 삼국지 (1~10) 합본 세트 나관중, 황석영
# 그로스 아이큐 Growth IQ 티파니 보바
# ...

# %% [markdown]
# ## Homework2 - 다음뉴스 기사 데이터 수집하기
# 네이버뉴스 기사 데이터 수집과 같은 방법으로 다음뉴스 기사 데이터를 1-3페이지까지 수집하는 수집기를 만들어봅니다. <br>
# **수집목표: 기사제목/기사 요약** <br>
# 1. 컨테이너, 기사제목, 기사 요약 선택자 찾기
# 2. 페이지를 변환하는 요청값 규칙 찾기
# 3. 코딩을 통해 데이터 수집기 만들기
# 4. 수집한 데이터를 원하는 방식으로 저장합니다. (csv, xlsx) <br>
# `참고: 다음 뉴스페이지는 역으로 headers가 있는 데이터 요청을 크롤링 시도라고 이해합니다. 이번에는 헤더값을 넣지 않고 수집기를 만들어봅니다.`

# %%
import requests
from bs4 import BeautifulSoup

for n in range(1, 4):
    raw = requests.get("https://search.daum.net/search?w=news&q=코알라&p="+str(n))
    html = BeautifulSoup(raw.text, 'html.parser')

    articles = html.select("div.wrap_cont")

    for ar in articles:
        title = ar.select_one("a.f_link_b").text
        summary = ar.select_one("p.f_eb.desc").text

        print(title)
        print(summary)
        # 기사별로 구분을 위해 구분선 삽입 
        print("="*50)
# Out:
# [세상만사] 위기의 코알라..물거품된 서식지 보호법
# 호주를 상징하는 동물 코알라 기름기 많은 유칼립투스 잎만 먹는 까다로운 입맛의 주인공 치명적인 귀여움으로 인기 독차지 -보호본능을 자극하는 동물 하지만... 코알라...
# ...
# 비례대표 '코알라'? '노무현 비하 논란' 휩싸인 세종시의회 누리집
# 31일 오전 9시께 세종시의회 누리집 모습. 무소속 강아무개 의원 프로필에 코알라 사진을 넣은 채 게시돼 있다. 세종시 누리집 갈무리 세종시의회 누리집 비례대표 소개란에...
# ...
# 디스코 알라잇, 디스하는 코알라 마약 도대체 뭐지 거저나 다름없...
# 디스코 알라잇' 관련 오퀴즈가 등장했다이날 출제된 오퀴즈는 "디스하는 코알라 디스코는 국가가 허락한 유일한 마약(?) OOOO를 위해 오늘도 살아간다"다.네이버에서...
# ...
# [여기는 호주] "저리가!"..코알라 공격하는 큰 까마귀 포착 (영상)
# [서울신문 나우뉴스] 코알라를 공격하는 큰 까마귀가 포착되어 화제다. 지난 26일(현지시간) 호주 채널 7뉴스의 보도에 의하면 이 장면은 남호주의 주도인 애들레이드에...
# ...
# [크랩] '멸종위기'라던 호주 코알라, 지금 어떻게 됐을까?
# 코알라 3분의 1 이상이 목숨을 잃게 만든 호주 산불. 그 이후 아기 코알라들이 태어났다는 반가운 소식입니다. 호주 파충류 공원(Australian Reptile Park)이 운영 중인...
# ...
# [카드뉴스] 코알라가 새끼에게 똥을 먹이는 이유...신기한 동물 상식
# 합니다. 그리고 그루밍을 할 때는 오줌의 양과 맞먹는 침을 사용하기도 하죠.다음! 코알라는 새끼에게 똥을 먹인다? 조금 놀랍지 않나요? 코알라는 식성이 특이해 오직...
# ...
# 호주 아기코알라 9마리 탄생 경사..30년내 멸종위기에 희망
# [노트펫]오스트레일리아 산불 이후 새끼 코알라 9마리가 태어나서, 멸종위기에 직면한 코알라에게 한 줄기 빛이 됐다고 영국 일간지 데일리메일이 지난 4일(현지시간) 보도...
# ...

# %% [markdown]
# # Part3

# %% [markdown]
# **참고** <br>
# 같은 선택자로 선택되는 데이터에 저장되어 있는 경우에는 아이디나 클래스로 선택자를 구분할 수 없고, 같은 태그 안의 같은 위치에 있기 때문에 상하관계를 통해서도 구분할 수 없습니다. 그럴때는 다음과 같은 방법을 사용하실 수 있습니다. <br>
# <br>
# `방법 1. 리스트 인덱싱 활용하기`
# <img src="image/23.png">

# %%
#코드를 실행하지 마시고 이용하는 방법만 참고해주세요!
movie = html.select("dl.lst_dsc")
for m in movie:
    info = m.select("dl.info_txt1 dd") 
    genre = info[0].select("a") 
    directors = info[1].select("a") 
    actors = info[2].select("a")

# %% [markdown]
# `방법 2. 선택자 응용하기(nth-of-type)` <br>
# 선택자 레벨에서도 이 문제를 해결할 수 있습니다. 아래와 같이 nth-of-type()을 활용하면 n번째 데이터를 선택할 수 있습니다. <br>
# `태그이름:nth-of-type(N)`방법을 활용하면 N번째 태그 데이터를 선택할 수 있습니다. <br>
# 프로그래밍 언어는 대부분을 숫자를 0부터 세지만 **`nth-of-type()`방법의 경우는 숫자를 1부터 세게 됩니다.** <br>
# 그리고 **`nth-of-type()`의 앞에는 클래스 또는 아이디가 올 수 없기 때문에** 해당하는 태그가 몇번째 태그인지도 꼭 확인해야합니다.

# %%
#코드를 실행하지 마시고 이용하는 방법만 참고해주세요!
movie = html.select("dl.lst_dsc") 
for m in movie:
    genre = m.select("dl.info_txt1 dd:nth-of-type(1) a") 
    directors = m.select("dl.info_txt1 dd:nth-of-type(2) a") 
    actors = m.select("dl.info_txt1 dd:nth-of-type(3) a")

# %% [markdown]
# ## Challenge1 - IMDb 영화정보 수집하기
# IMDb(https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth) 의 현재 상영중 영화목록에서 상영 중인 영화의 제목 /  감독 / 배우 데이터를 수집합니다. <br>
# 1. 컨테이너, 제목, 평점, 감독, 배우 데이터를 선택할 수 있는 선택자를 찾습니다.
# 2. 파이썬을 통해 데이터를 수집할 수 있는 데이터 수집기를 만듭니다.
# 3. (심화) 조건문을 활용하여 Action 장르의 영화만 출력합니다.

# %% [markdown]
# ### 리스트 사용

# %%
# IMDb 홈페이지에 데이터 요청하기
raw = requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                   headers={"User-Agent": "Mozilla/5.0"})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movies = html.select("td.overview-top ")

# 컨테이너를 반복하며 상세데이터(제목, 감독, 배우) 수집하기
for m in movies:
    title = m.select_one("h4 > a").text

    # 감독과 배우가 모두 div.txt-block으로 선택되는 태그에 저장되어 있으므로
    # 리스트를 저장하여 첫번째: 감독/ 두번째: 배우를 구분합니다.
    info = m.select("div.txt-block")
    director = info[0].select("a")
    actor = info[1].select("a")
    
    print("제목:", title)
    # print(score)

    print("감독:")
    for d in director:
        print(d.text)

    print("배우:")
    for a in actor:
        print(a.text)

    print("=" * 50)
# Out:
# 제목:  Ava (2020)
# 감독:
# Tate Taylor
# 배우:
# Jessica Chastain
# John Malkovich
# Common
# Geena Davis
# ...
# 제목:  Kajillionaire (2020)
# 감독:
# Miranda July
# 배우:
# Evan Rachel Wood
# Mark Ivanir
# Gina Rodriguez
# Debra Winger
# ...
# 제목:  The Last Shift (2020)
# 감독:
# Andrew Cohn
# 배우:
# Richard Jenkins
# Shane Paul McGhie
# Ed O'Neill
# Allison Tolman
# ...
# 제목:  Ottolenghi and the Cakes of Versailles (2020)
# 감독:
# Laura Gabbert
# 배우:
# Dominique Ansel
# Sam Bompas
# Dinara Kasko
# Deborah Krohn
# ...
# 제목:  Draupadi Unleashed (2019)
# 감독:
# Tony Stopperan
# Nisha Sabharwal
# 배우:
# Cas Anvar
# Taaha Shah Badusha
# Abi Bais
# Pooja Batra
# ...

# %% [markdown]
# ### nth-of-type 사용

# %%
# IMDb 홈페이지에 데이터 요청하기
raw = requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                   headers={"User-Agent":"Mozilla/5.0"})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movies = html.select("td.overview-top ")

# 컨테이너를 반복하며 상세데이터(제목, 감독, 배우) 수집하기
for m in movies:
    title = m.select_one("h4 > a").text
    
    # 감독, 배우는 여러명일 수 있으므로 select를 활용해서 리스트로 저장합니다.
    # 원하는 데이터가 컨테이너의 자식관계에 있을 때는 자식 선택자(>)를 먼저 써줄 수도 있습니다.
    director = m.select("> div:nth-of-type(3) a")
    actor = m.select("> div:nth-of-type(4) a")

    print("제목:", title)
    # print(score)

    print("감독:")
    for d in director:
        print(d.text)

    print("배우:")
    for a in actor:
        print(a.text)

    print("="*50)

# %% [markdown]
# ## Challenge2 - IMDb 포스터 저장하기
# IMDb(https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth) 의 현재 상영중 영화목록에서 현재 상영중 영화의 상세페이지에 접속해 포스터를 저장합니다. <br>
# 1. 상세 페이지에 접속할 수 있는 링크주소를 수집합니다.
# 2. 상세 페이지의 포스터를 선택할 수 있는 선택자를 찾습니다.
# 3. 포스터 이미지가 저장되어 있는 속성을 찾아 포스터를 다운 받습니다. <br>
#
# `다운받은 포스터와 소스코드가 섞이지 않게하기 위해서 poster 디렉토리를 만들어 포스터 이미지를 저장합니다.`

# %%
import requests
from bs4 import BeautifulSoup

from urllib.request import urlretrieve

# IMDb 홈페이지에 데이터 요청하기
raw = requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                   headers={"User-Agent":"Mozilla/5.0"})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집하기
movies = html.select("td.overview-top ")

for m in movies:
    title = m.select_one("h4 > a")
    
    # 제목에서 링크 연결주소를 가져와 저장하기
    url = title.attrs["href"]

    # 상세페이지에 접속해서 데이터를 요청하기
    raw_each = requests.get("https://www.imdb.com"+url, headers={"User-Agent":"Mozilla/5.0"})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')

    # 포스터 데이터를 선택해서 src값 가져오기
    # 포스터 선택자: div.poster img
    poster = html_each.select_one("div.poster img")
    src = poster.attrs["src"]

    # urlretrieve 함수를 사용해서 이미지 저장하기
    # poster 폴더 안에 이미지 저장하기
    urlretrieve(src, 'poster/'+ title.text[:4]+'.png')

# %% [markdown]
# ## Homework - 네이버 쇼핑 best100 데이터 수집하기
# 네이버 쇼핑 best100 - 예매순위 페이지(https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000) 에서 제품별 상세페이지에 접속하여 제품의 판매처와 판매가를 수집합니다. <br>
# <img src="image/28.png"> <br> <br> <img src="image/29.png">
# 1. 네이버 쇼핑 best100 페이지에서 각 제품 상세페이지로 들어갈 수 있는 링크를 찾습니다.
# 2. 상세페이지에서 원하는 데이터를 찾을 수 있는 선택자를 찾습니다.
# 3. 코딩을 통해 데이터 수집기를 완성합니다.
#
# `hint) 네이버 쇼핑 best100 예매페이지의 경우, a태그에 저장되있는 링크는 완벽한 URL의 형태를 띄고 있습니다. 굳이 기존페이지의 주소를 붙여주지 않아도 상관없습니다 :)` <br>

# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get("https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000",
                   headers={"User-Agent":"Mozilla/5.0"})
html = BeautifulSoup(raw.text, 'html.parser')

# 컨테이너 수집
contain = html.select("li._itemSection")
contain_1=contain[:25]
contain_2=contain[25:50]
contain_3=contain[50:75]
contain_4=contain[75:]

# %%
# 수집한 컨테이너 반복하기
for c in contain_1:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# 수집한 컨테이너 반복하기
for c in contain_2:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# 수집한 컨테이너 반복하기
for c in contain_3:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# 수집한 컨테이너 반복하기
for c in contain_4:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# Out:
# 타미힐피거 남녀공용 F W 크루넥 맨투맨 SW
# ...
# 판매처: 현대Hmall
# 판매가: 인기 37,900
# ...
# 판매처: GSSHOP
# 판매가: 33,750
# ...
# 판매처: 롯데홈쇼핑
# 판매가: 32,670
# ...
# 판매처: 롯데ON
# 판매가: 32,670
# ...
# 판매처: thehappyhouse
# 판매가: 37,900
# ...
# 판매처: 패션플러스
# 판매가: 34,870
# ...
# 판매처: CJ몰
# 판매가: 38,900
# ...
# 판매처: G마켓
# 판매가: 35,190
# ...
# 판매처: G9
# 판매가: 40,300
# ...
# 판매처: 옥션
# 판매가: 36,670
# ...
# 나이키 맨투맨 후드티 804343-063
# ...
# 판매처: G마켓
# 판매가: 인기 27,510
# ...
# 판매처: 기브유몰
# 판매가: 24,730
# ...
# 판매처: 인터파크
# 판매가: 27,500
# ...
# 판매처: 에이플래닛
# 판매가: 26,000
# ...
# 판매처: 티몬
# 판매가: 29,900
# ...
# 판매처: 원샷팩토리
# 판매가: 29,000
# ...
# 판매처: 반지하
# 판매가: 26,000
# ...
# 판매처: 롯데ON
# 판매가: 35,550
# ...
# 판매처: 쿠팡
# 판매가: 39,900
# ...
# 판매처: AK몰
# 판매가: 38,410
# ...
# 지오다노 여 포플린 셔츠 05340501 340501
# ...
# 판매처: 롯데홈쇼핑
# 판매가: 인기 18,370
# ...
# 판매처: 11번가
# 판매가: 18,190
# ...
# 판매처: 현대Hmall
# 판매가: 16,650
# ...
# 판매처: CJmall
# 판매가: 18,000
# ...
# 판매처: G마켓
# 판매가: 18,380
# ...
# 판매처: 지오다노공식온라인스토어
# 판매가: 29,850
# ...
# 판매처: G9
# 판매가: 17,630
# ...
# 판매처: AK플라자 평택점
# 판매가: 25,330
# ...
# 판매처: 지오다노
# 판매가: 34,630
# ...
# 판매처: 옥션
# 판매가: 18,380
# ...
# 폴로랄프로렌 걸즈 케이블 꽈배기 니트 가디...
# ...
# 판매처: 시카고패션아울렛
# 판매가: 인기 49,800
# ...
# 판매처: FRED store
# 판매가: 30,900
# ...
# 판매처: 뉴욕프렌즈
# ...

# %%
# 수집한 컨테이너 반복하기
for c in contain_2:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# Out:
# 개별포장 노라인팬티 심리스팬티 무봉제 여...
# ...
# 판매처: 재이앤컴퍼니
# 판매가: 인기 670
# ...
# 판매처: 개구쟁이
# 판매가: 670
# ...
# 판매처: JD-Studio
# 판매가: 900
# ...
# 판매처: 레나마켓
# 판매가: 1,530
# ...
# 판매처: 데일리원샵
# 판매가: 860
# ...
# 판매처: 굿세라
# 판매가: 880
# ...
# 판매처: 유연하다
# 판매가: 980
# ...
# 판매처: 11번가
# 판매가: 7,130
# ...
# 판매처: 데일리 피플
# 판매가: 1,900
# ...
# 판매처: 위메프
# 판매가: 1,180
# ...
# 베이직바이블 9부10부 시크릿 히든밴딩 구김...
# ...
# 판매처: 베이직바이블 basicbible
# 판매가: 인기 14,300
# ...
# 판매처: 베이직 바이블
# 판매가: 14,300
# ...
# 판매처: 쿠팡
# 판매가: 15,900
# ...
# 판매처: 옥션
# 판매가: 15,900
# ...
# 판매처: GSSHOP
# 판매가: 16,900
# ...
# 판매처: SSG닷컴
# 판매가: 15,560
# ...
# 판매처: 신세계몰
# 판매가: 15,717
# ...
# 판매처: 이마트몰
# 판매가: 15,717
# ...
# 탑텐 여성 플러피플리스 하이넥 집업 MSZ4T...
# ...
# 판매처: TOPTEN10
# 판매가: 인기 15,900
# ...
# 판매처: 탑텐 스토어
# 판매가: 15,900
# ...
# 판매처: 티몬
# 판매가: 17,320
# ...
# 세인트제임스 밍콰이어 스트라이프 티셔츠 ...
# ...
# 판매처: 미쿡제
# 판매가: 인기 59,900
# ...
# 판매처: 샵팜
# 판매가: 59,900
# ...
# 판매처: 미쿡제
# 판매가: 59,900
# ...
# 판매처: 멸치쇼핑
# 판매가: 59,800
# ...
# 판매처: 샵팜
# 판매가: 59,900
# ...
# 아디다스 파이어버드 트랙팬츠 ED6897
# ...
# 판매처: 훌리건
# 판매가: 인기 33,900
# ...
# 판매처: 아디다스
# 판매가: 49,500
# ...
# 판매처: 비비엘유이코리아
# 판매가: 31,350
# ...
# 판매처: GSSHOP
# 판매가: 49,900
# ...
# 판매처: 현대김포 아디다스
# 판매가: 49,500
# ...
# 판매처: 더현대닷컴
# 판매가: 49,500
# ...

# %%
# 수집한 컨테이너 반복하기
for c in contain_3:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# Out:
# 라코스테 20 FW 여성 베이직 V넥 가디건 AF...
# ...
# 판매처: 라코스테 우먼
# 판매가: 인기 265,050
# ...
# 판매처: 현대Hmall
# 판매가: 227,670
# ...
# 판매처: 11번가
# 판매가: 220,960
# ...
# 판매처: CJmall
# 판매가: 220,970
# ...
# 판매처: 라코스테 우먼
# 판매가: 265,050
# ...
# 판매처: 롯데홈쇼핑
# 판매가: 245,270
# ...
# 판매처: G마켓
# 판매가: 239,940
# ...
# 판매처: 옥션
# 판매가: 237,150
# ...
# 판매처: 현대무역 라코스테 우먼
# 판매가: 265,050
# ...
# 판매처: SSG닷컴
# 판매가: 257,099
# ...
# 폴로랄프로렌 여성 베이직 코튼 브이넥 꽈배...
# ...
# 판매처: 시카고패션아울렛
# 판매가: 인기 76,800
# ...
# 판매처: 마켓토마토
# 판매가: 62,000
# ...
# 판매처: 시카고패션아울렛
# 판매가: 76,800
# ...
# 판매처: 미쿡제
# 판매가: 77,000
# ...
# 판매처: 미쿡제
# 판매가: 77,000
# ...
# 폴로랄프로렌 여성 New 브이넥 케이블 면니...
# ...
# 판매처: 젬스뉴욕
# 판매가: 인기 114,900
# ...
# 판매처: 젬스뉴욕
# 판매가: 114,900
# ...
# 지오다노 공용 코튼 져지 크루넥 3팩 패키지...
# ...
# 판매처: GSSHOP
# 판매가: 인기 12,840
# ...
# 판매처: 엘롯데
# 판매가: 13,700
# ...
# 판매처: 지오다노컨셉샵
# 판매가: 15,240
# ...
# 판매처: 현대Hmall 스토어
# 판매가: 15,840
# ...
# 판매처: 현대Hmall
# 판매가: 15,840
# ...
# 판매처: 롯데ON
# 판매가: 13,700
# ...
# 판매처: NS홈쇼핑
# 판매가: 13,670
# ...
# 판매처: 11번가
# 판매가: 15,840
# ...
# 판매처: 신세계백화점
# 판매가: 15,660
# ...
# 판매처: G마켓
# 판매가: 16,510
# ...
# 몽클레르 클로에 KHLOE 롱패딩
# ...
# 판매처: 소비메이커
# 판매가: 인기 2,070,000
# ...
# 판매처: 유로닷컴
# 판매가: 2,350,000
# ...
# 판매처: 엘리스런던
# ...

# %%
# 수집한 컨테이너 반복하기
for c in contain_4:
    
    # 제목 수집해서 링크 저장하기
    title = c.select_one("p.cont a")
    url = title.attrs["href"]
    print(title.text.strip());print("="*50)

    # 상세페이지 데이터 요청하기
    raw_each = requests.get(url, headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'})
    html_each = BeautifulSoup(raw_each.text, 'html.parser')
    cont=html_each.select("tr._itemSection")
    i=0
    while i<len(html_each.select("td.price")):
        price=cont[i].select_one("td.price").text.strip()
        try:
            shop=cont[i].select_one("td.mall_area a img").attrs["alt"]
            print("판매처:", shop);print("판매가:", price);print("="*50)
        except:
            shop=cont[i].select_one("td.mall_area a").text.strip()
            print("판매처:", shop);print("판매가:", price);print("="*50)
        i+=1
# Out:
# 라코스테 남성 방모 와이넥 가디건 20FW AH...
# ...
# 판매처: 라코스테 남성
# 판매가: 인기 265,050
# ...
# 판매처: 11번가
# 판매가: 228,170
# ...
# 판매처: G마켓
# 판매가: 232,410
# ...
# 판매처: 롯데홈쇼핑
# 판매가: 245,270
# ...
# 판매처: 위메프
# 판매가: 242,730
# ...
# 판매처: AK몰
# 판매가: 251,800
# ...
# 판매처: SSG닷컴
# 판매가: 257,099
# ...
# 판매처: 신세계몰
# 판매가: 257,099
# ...
# 판매처: 롯데ON
# 판매가: 279,000
# ...
# 나이키 윈드러너 후디 재킷 AR2192-010
# ...
# 판매처: 멸치쇼핑
# 판매가: 인기 62,500
# ...
# 판매처: 인터파크
# 판매가: 76,300
# ...
# 판매처: 나이키공식홈페이지
# 판매가: 119,000
# ...
# 판매처: 11번가
# 판매가: 77,880
# ...
# 판매처: GSSHOP
# 판매가: 76,160
# ...
# 판매처: 로미스포츠
# 판매가: 98,000
# ...
# 판매처: 현대Hmall
# 판매가: 119,000
# ...
# 아뜨랑스 매끄러운 광택감이 돋보이는 베이...
# ...
# 판매처: 아뜨랑스
# 판매가: 인기 15,860
# ...
# 판매처: 아뜨랑스
# 판매가: 15,860
# ...
# 판매처: 아뜨랑스윈도우
# 판매가: 15,860
# ...
# 판매처: 아뜨랑스
# 판매가: 15,860
# ...
# 판매처: G마켓
# 판매가: 25,650
# ...
# 판매처: 11번가
# 판매가: 23,760
# ...
# 아디다스 부클 자켓 BOUCLETTE JKT GD3522
# ...
# 판매처: SSG닷컴
# 판매가: 인기 52,083
# ...
# 판매처: G마켓
# 판매가: 58,620
# ...
# 판매처: 신세계몰
# 판매가: 56,002
# ...
# 판매처: 아디다스 오리지널스
# 판매가: 76,300
# ...
# 판매처: 롯데ON
# 판매가: 54,170
# ...
# 판매처: G9
# 판매가: 55,910
# ...
# 판매처: 옥션
# 판매가: 71,380
# ...
# 판매처: W몰 아디다스 오리지널스
# 판매가: 76,300
# ...
# 판매처: 롯데홈쇼핑
# 판매가: 68,930
# ...
# 판매처: 롯데백화점영등포점
# ...

# %% [markdown]
# `네이버는 한꺼번에 너무 많은 데이터를 요청하면 '요청값이 너무 많습니다'라는 메세지를 띄우면서 원하는 정보를 주지 않습니다 :(` <br>
# `따라서 반복문을 나누어 작성하고 한번에 25개 제품에 대한 데이터를 요청하는 방식으로 코드를 작성하였습니다!`

# %% [markdown]
# # Part4

# %% [markdown]
# ## Challenge1 - 파파고 영단어 해석기 만들기

# %% [markdown]
# <img src="image/27.png">

# %% [markdown]
# Selenium을 사용해서 파파고(https://papago.naver.com)에서 "seize the day"라는 문장을 입력, 번역결과를 출력하는 프로그램을 만들어봅니다.
# 1. 파파고 번역 서비스 이용 절차를 적어봅니다.
# 2. 지연시간이 필요한 부분을 생각해봅니다.
# 3. 코딩을 통해 번역결과를 출력합니다.
# `입력도구(input, textarea)를 찾아 .send_keys를 사용하세요.`

# %%
from selenium import webdriver
import time

# 크롬창(웹드라이버) 열기
driver = webdriver.Chrome("./chromedriver")

# 파파고 페이지 접속
driver.get("https://papago.naver.com")

# 페이지 접속 후 시간 지연
time.sleep(0.5)

# 입력창에 검색어 입력
input_box = driver.find_element_by_css_selector("textarea#txtSource")
input_box.send_keys("seize the day")

# 번역 버튼 클릭
button = driver.find_element_by_css_selector("button#btnTranslate")
button.click()

# 버튼 클릭 후 시간 지연 & 검색결과 출력
time.sleep(0.5)
result = driver.find_element_by_css_selector("div#txtTarget").text
print(result)

# 크롬창 닫기
driver.close()

# %% [markdown]
# ## Challenge2 - 구글지도 데이터 수집하기
# 구글지도(https://www.google.com/maps/) 에 카페를 검색해서 검색된 카페들이 이름, 평점, 주소를 수집합니다.
# 1. 구글지도에서 검색하고 결과를 확인하는 절차를 생각해봅니다.
# 2. 컨테이너, 이름, 평점, 주소를 선택할 수 있는 선택자를 찾습니다.
# 3. 코딩을 통해 데이터를 수집합니다.
#
# `구글의 경우 지연시간을 길게 주셔야 합니다. (평균 5 ~ 10초)`

# %%
from selenium import webdriver
import time

# 크롬창(웹드라이버) 열기
driver = webdriver.Chrome("./chromedriver")

# 구글 지도 접속하기
driver.get("https://www.google.com/maps/")

# 검색창에 "카페" 입력하기
searchbox = driver.find_element_by_css_selector("input#searchboxinput")
searchbox.send_keys("카페")

# 검색버튼 누르기
searchbutton = driver.find_element_by_css_selector("button#searchbox-searchbutton")
searchbutton.click()

# 여러 페이지(999)에서 반복하기
for i in range(999):
    # 시간 지연
    time.sleep(3)

    # 컨테이너(가게) 데이터 수집 // div.section-result-content
    stores = driver.find_elements_by_css_selector("div.section-result-content")

    for s in stores:
        # 가게 이름 데이터 수집 // h3.section-result-title
        title = s.find_element_by_css_selector("h3.section-result-title").text

        # 평점 데이터 수집 // span.cards-rating-score
        # 평점이 없는 경우 에러 처리
        try:
            score = s.find_element_by_css_selector("span.cards-rating-score").text
        except:
            score = "평점없음"

        # 가게 주소 데이터 수집 // span.section-result-location
        addr = s.find_element_by_css_selector("span.section-result-location").text

        print(title, "/", score, "/", addr)

    # 다음페이지 버튼 클릭 하기
    # 다음페이지가 없는 경우(데이터 수집 완료) 에러 처리
    try:
        nextpage = driver.find_element_by_css_selector("button#n7lv7yjyC35__section-pagination-button-next")
        nextpage.click()
    except:
        print("데이터 수집 완료.")
        break

# 크롬창 닫기
driver.close()

# %% [markdown]
# ## Homework - 네이버/페이스북 로그인하기
# Selenium을 활용하여 네이버 로그인 페이지(https://nid.naver.com)와 페이스북(https://www.facebook.com)에 자동으로 로그인하는 프로그램을 만들어 봅니다.
# 1. 로그인 절차에 대해 생각해봅니다.
#
# 2. 아이디/비밀번호를 입력하고 로그인버튼을 누를 수 있는 선택자를 찾습니다.
#
# 3. 코딩을 통해 자동 로그인 장치를 만들어봅니다.
#
# `로그인에 성공하더라도 대형 서비스에서는 자동 로그인 방지 장치 때문에 서비스 이용은 어렵습니다. :)` <br>
# `과제를 제출하실 때는 본인의 아이디나 비밀번호를 공개하실 필요는 없습니다 :)`

# %%
from selenium import webdriver

# 계정정보 입력
id = "아이디"
password = "비밀번호"

# 크롬창(웹드라이버) 열기
driver = webdriver.Chrome("./chromedriver")

# 네이버 로그인 페이지 접속
driver.get("https://nid.naver.com")

# 아이디 입력
input_id = driver.find_element_by_css_selector("input#id")
input_id.send_keys(id)

# 비밀번호 입력
input_password = driver.find_element_by_css_selector("input#pw")
input_password.send_keys(password)

# 로그인 버튼 클릭
login = driver.find_element_by_css_selector("input.btn_global")
login.click()
